# %%
import Data_Preprocessing.Graph_Data as gd
from Data_Preprocessing.Graph_Data import Molecule_data
from models.AttentiveFPModel import AttentiveFP
import matplotlib.pyplot as plt
import torch
from torch_geometric.loader import DataLoader

from models.gat import GATNet
import torch.nn as nn
from models.gcn import GCNNet
from models.gat_gcn import GAT_GCN
from models.ginconv import GINConvNet

# %%
if torch.cuda.is_available():  
    device = "cuda:1"
    print("cuda:1")
else:  
    device = "cpu" 
    print(torch.cuda.is_available())
# Out:
# cuda:1

# %%
test_data = Molecule_data(root='data', dataset='test_data_set',y=None,smile_graph=None,smiles=None)
train_data = Molecule_data(root='data', dataset='train_data_set',y=None,smile_graph=None,smiles=None)

# %%
TRAIN_BATCH_SIZE = 17

# %%
test_loder  = DataLoader(test_data,batch_size=TRAIN_BATCH_SIZE,shuffle=True)
train_loder   = DataLoader(train_data,batch_size=TRAIN_BATCH_SIZE,shuffle=True)

# %%
model = AttentiveFP(in_channels=114, hidden_channels=292, out_channels=1,
                    num_layers=3, num_timesteps=1,
                    dropout= 0.05115077176824934).to(device)

# %%
model = model.to(device)

# %%
model_file_name = 'Graph_attention_best_12.model'
model.load_state_dict(torch.load(model_file_name))
# Out:
# <All keys matched successfully>

# %%
y_pred_arr = []
target_array = []
for data in test_loder:
    data = data.to(device)
    y_pred = model(data.x.float(), data.edge_index,data.batch)
    y_pred_arr.append(y_pred)
    target_array.append(data.y.float())

# %%
y_ped=torch.cat(y_pred_arr).view(-1).cpu().detach().numpy()
y_true=torch.cat(target_array).cpu().detach().numpy()

# %%
plt.scatter(y_ped,y_true,s=10,marker ="s",c=y_true,cmap=plt.get_cmap('plasma'))
plt.plot(y_true,y_true)
plt.show()

# %%
plt.plot(y_ped, y_true, '-p', color='gray',
         markersize=15, linewidth=4,
         markerfacecolor='white',
         markeredgecolor='gray',
         markeredgewidth=2)
plt.ylim(-1.2, 10.2);

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
import math

# %%
MSE = mean_squared_error(y_true, y_ped)
print(MSE)
# Out:
# 0.14799948

# %%
print(mean_absolute_error(y_true,y_ped))
# Out:
# 0.27835855

# %%
RMSE = math.sqrt(MSE)
print("Root Mean Square Error:\n")
print(RMSE)
# Out:
# Root Mean Square Error:
#
# 0.3847070058716202

# %% [markdown]
# # Train

# %%
y_pred_arr_train = []
target_array_train = []
for data in train_loder:
    data = data.to(device)
    y_pred = model(data.x.float(), data.edge_index,data.batch)
    y_pred_arr_train.append(y_pred.float())
    target_array_train.append(data.y.float())
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-17-e186a2af07d5> in <module>
#       3 for data in train_loder:
#       4     data = data.to(device)
# ----> 5     y_pred = model(data.x.float(), data.edge_index,data.batch)
#       6     y_pred_arr_train.append(y_pred.float())
#       7     target_array_train.append(data.y.float())
#
# ~/anaconda3/envs/band/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/BandGap_Predicator/Training/models/AttentiveFPModel.py in forward(self, x, edge_index, batch)
#     116         x = F.leaky_relu_(self.lin1(x))
#     117
# --> 118         h = F.elu_(self.atom_convs[0](x, edge_index))
#     119         h = F.dropout(h, p=self.dropout, training=self.training)
#     120         x = self.atom_grus[0](h, x).relu_()
#
# ~/anaconda3/envs/band/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/BandGap_Predicator/Training/models/AttentiveFPModel.py in forward(self, x, edge_index)
#      38
#      39     def forward(self, x: Tensor, edge_index: Adj) -> Tensor:
# ---> 40         out = self.propagate(edge_index, x=x)
#      41         out += self.bias
#      42         return out
#
# ~/anaconda3/envs/band/lib/python3.6/site-packages/torch_geometric/nn/conv/message_passing.py in propagate(self, edge_index, size, **kwargs)
#     267                 if res is not None:
#     268                     msg_kwargs = res[0] if isinstance(res, tuple) else res
# --> 269             out = self.message(**msg_kwargs)
#     270             for hook in self._message_forward_hooks.values():
#     271                 res = hook(self, (msg_kwargs, ), out)
#
# ~/BandGap_Predicator/Training/models/AttentiveFPModel.py in message(self, x_j, x_i, index, ptr, size_i)
#      46                 size_i: Optional[int]) -> Tensor:
#      47
# ---> 48         x_j = F.leaky_relu_(self.lin1(x_j))
#      49         alpha_j = (x_j * self.att_l).sum(dim=-1)
#      50         alpha_i = (x_i * self.att_r).sum(dim=-1)
#
# ~/anaconda3/envs/band/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/anaconda3/envs/band/lib/python3.6/site-packages/torch/nn/modules/linear.py in forward(self, input)
#      92
#      93     def forward(self, input: Tensor) -> Tensor:
# ---> 94         return F.linear(input, self.weight, self.bias)
#      95
#      96     def extra_repr(self) -> str:
#
# ~/anaconda3/envs/band/lib/python3.6/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#    1751     if has_torch_function_variadic(input, weight):
#    1752         return handle_torch_function(linear, (input, weight), input, weight, bias=bias)
# -> 1753     return torch._C._nn.linear(input, weight, bias)
#    1754
#    1755
#
# RuntimeError: CUDA out of memory. Tried to allocate 2.00 MiB (GPU 1; 11.91 GiB total capacity; 11.14 GiB already allocated; 3.00 MiB free; 11.16 GiB reserved in total by PyTorch)

# %%
y_ped_train = torch.cat(y_pred_arr_train).view(-1).cpu().detach().numpy()
y_true_train = torch.cat(target_array_train).cpu().detach().numpy()

# %%
plt.scatter(y_ped_train,y_true_train,s=5,c=y_true_train,cmap=plt.get_cmap('plasma'))
plt.plot(y_true_train,y_true_train)
plt.show()

# %%
print(mean_absolute_error(y_true_train,y_ped_train))

# %%
MSE = mean_squared_error(y_true_train, y_ped_train)
print(MSE)

# %%
RMSE = math.sqrt(MSE)
print("Root Mean Square Error:\n")
print(RMSE)
