# %%
import pandas as pd
import numpy as np

from rdkit import Chem
from rdkit.Chem import Draw
import networkx as nx
from torch_geometric.datasets import MoleculeNet
import matplotlib.pyplot as plt

import torch
import os
import pandas as pd
import numpy as np
import json,pickle
from collections import OrderedDict
from rdkit import Chem
from rdkit.Chem import MolFromSmiles
import networkx as nx

from torch_geometric.data import InMemoryDataset, Data
from torch_geometric.loader import DataLoader

from sklearn.model_selection import train_test_split
from tqdm.notebook import tqdm
import torch
import torch.nn as nn
import Data_Preprocessing.Graph_Data as gd
from Data_Preprocessing.Graph_Data import Molecule_data
from models.AttentiveFPModel import AttentiveFP
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-724da98f7dc0> in <module>
#      25 import torch
#      26 import torch.nn as nn
# ---> 27 import Data_Prep.Graph_Data as gd
#      28 from Data_Prep.Graph_Data import Molecule_data
#      29 from models.AttentiveFPModel import AttentiveFP
#
# ModuleNotFoundError: No module named 'Data_Prep'

# %%
def createFoldsData():
    iy = 0
    folds = 5
    for fold in tqdm(range(folds)):
        df_train = pd.read_csv('New_fold/fold_'+str(iy)+'_'+'x_train.csv')
        df_test  = pd.read_csv('New_fold/fold_'+str(iy)+'_'+'x_test.csv')
        smiles = df_train['SMILE']
        codIds = df_train['CODID']
        band_gap = df_train['bgs']
        band_gap = band_gap.to_numpy()

        smiles_test = df_test['SMILE']
        codIds_test = df_test['CODID']
        band_gap_test = df_test['bgs']
        band_gap_test = band_gap_test.to_numpy()


        smile_graph = {}
        band_gap_arr = []
        smiles_array = []

        for i,smile in enumerate(smiles):
            g = gd.smile_to_graph(smile)
            if g != None:
                smile_graph[smile] = g
                band_gap_arr.append(band_gap[i])
                smiles_array.append(smile)

        smile_graph_test = {}
        band_gap_arr_test = []
        smiles_array_test = []

        for i,smile in enumerate(smiles_test):
            g = gd.smile_to_graph(smile)
            if g != None:
                smile_graph_test[smile] = g
                band_gap_arr_test.append(band_gap_test[i])
                smiles_array_test.append(smile)

        train_data = Molecule_data(root='data', dataset='train_data_set_fold_'+str(iy),y=band_gap_arr,
                                   smile_graph=smile_graph,smiles=smiles_array)

        train_data = Molecule_data(root='data', dataset='test_data_set_fold_'+str(iy),y=band_gap_arr_test,
                                   smile_graph=smile_graph_test,smiles=smiles_array_test)

        iy+=1

# %%
df = pd.read_csv('Data_Prep/omdb_smile_data_set.csv')

# %%
smiles = df['SMILE']
codIds = df['CODID']
band_gap = df['bgs']

# %%
band_gap = band_gap.to_numpy()

# %%
def createFoldsCsv():
    from sklearn.model_selection import StratifiedKFold
    from sklearn.model_selection import KFold
    kf = KFold(n_splits=5,shuffle = True, random_state = 42)
    ix = 0
    train1 = df
    for train_index, test_index in (kf.split(train1)):
        print ("TRAIN:", len(train_index), "TEST:", len(test_index))
        X_train,X_test=train1.iloc[train_index], train1.iloc[test_index]
        X_train.to_csv('New_fold/fold_'+str(ix)+'_'+'x_train.csv',index=False)
        X_test.to_csv('New_fold/fold_'+str(ix)+'_'+'x_test.csv',index=False)
        ix+=1
    createFoldsData()

# %%
processed_data_file_train = 'data/processed/' + 'test_data_set_fold_'+str(0)+'.pt'
processed_data_file_test = 'data/processed/'  + 'train_data_set_fold_'+str(0)+'.pt'
if ((not os.path.isfile(processed_data_file_train)) or (not os.path.isfile(processed_data_file_test))):
        print('please run create_data.py to prepare data in pytorch format!')
        createFoldsCsv()

# %%
if torch.cuda.is_available():  
    device = "cuda:3"
    print("cuda:3")
else:  
    device = "cpu" 
    print(torch.cuda.is_available())
# Out:
# False

# %%
# training function at each epoch
def train(model, device, train_loader, optimizer, epoch,loss_fn):
    #print('Training on {} samples...'.format(len(train_loader1.dataset)))
    model.train()
    Loss = []
    for data in train_loader:
        data = data.to(device)
        optimizer.zero_grad()
        output = model(data.x.float(), data.edge_index,data.batch)
        loss = loss_fn(output, data.y.view(-1, 1).float().to(device))
        loss.backward()
        optimizer.step()
        Loss.append(loss.item())
    nploss = np.asarray(Loss)
    avg_loss = np.average(nploss)
    return avg_loss

# %%
def predicting(model, device, loader,loss_fn):
    model.eval()
    total_loss=total_example=0
    total_preds = torch.Tensor()
    total_labels = torch.Tensor()
    
    with torch.no_grad():
        for data in loader:
            data = data.to(device)
            output = model(data.x.float(), data.edge_index,data.batch)
            
            loss = loss_fn(output, data.y.view(-1, 1).float().to(device))
            total_loss+=loss
            total_example+=1
    return total_loss/total_example

# %%
#LR = 0.005
LR = 9.797464088146652e-05
#LR = 0.0028894537419258915
LOG_INTERVAL = 20
NUM_EPOCHS = 3000
results = []

# %%
class RMSELoss(nn.Module):
    def __init__(self):
        super().__init__()
        self.mse = nn.MSELoss()
        
    def forward(self,yhat,y):
        return torch.sqrt(self.mse(yhat,y))

# %%
loss_fn = nn.L1Loss()

# %%
best_ret = []
best_mse = 0.80
best_ci = 0
best_epoch = -1

# %%
folds = 5
results = []
best_mae_arr = []

for fold in tqdm(range(folds)):
    val_losses = []
    train_losses = []
    mae_arr = []
    patience = 16
    trigger_times = 0
    the_last_loss = 100
    
    model_file_name = 'saved_models/model_' +  str(fold) +  '.model'
    result_file_name = 'result_' + str(fold) +  '.csv'
    
    train_data = Molecule_data(root='data', dataset='train_data_set_fold_'+str(fold),y=None,smile_graph=None,smiles=None)
    test_data = Molecule_data(root='data', dataset='test_data_set_fold_'+str(fold),y=None,smile_graph=None,smiles=None)
    
    TRAIN_BATCH_SIZE = 40
    
    train_loder   = DataLoader(train_data,batch_size=TRAIN_BATCH_SIZE,shuffle=True)
    test_loder  = DataLoader(test_data,batch_size=TRAIN_BATCH_SIZE,shuffle=True)
    model = AttentiveFP(in_channels=112, hidden_channels=279, out_channels=1,
                    num_layers=3, num_timesteps=2,
                    dropout=0.047352327938708194).to(device)
    best_ret = []
    
    model = model.cuda(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=LR)
    best_mae = 0.00
    
    for epoch in range(NUM_EPOCHS):
        train_loss=train(model, device, train_loder, optimizer, epoch+1,loss_fn)
        test_loss = predicting(model, device, test_loder,loss_fn)
        
        print('Epoch% d: Train mae: %2.5f\t val mae: %2.5f\t'
          %(epoch, train_loss,test_loss.item()))
        
        ret = [epoch,train_loss,test_loss.item()]
        
        train_losses.append(train_loss)
        val_losses.append(test_loss.item())
        
        # Early stopping
        the_current_loss = test_loss.item()
        
        best_ret.append(ret)
        
        if the_current_loss > the_last_loss:
            trigger_times += 1
            print('trigger times:', trigger_times)
            
            if trigger_times >= patience:
                print('Early stopping!\nStart to test process.')
                break
        else:
            ret = [epoch,train_loss,test_loss.item()]
            trigger_times = 0
            best_mae = the_current_loss
            the_last_loss = the_current_loss
            
            torch.save(model.state_dict(), model_file_name)

    results.append(best_ret)
    best_mae_arr.append(best_mae)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=5.0), HTML(value='')))
# Epoch 0: Train mae: 0.99101	 val mae: 0.72999
# Epoch 1: Train mae: 0.65619	 val mae: 0.61133
# Epoch 2: Train mae: 0.58458	 val mae: 0.58842
# Epoch 3: Train mae: 0.56527	 val mae: 0.53808
# Epoch 4: Train mae: 0.53395	 val mae: 0.54294
# trigger times: 1
# Epoch 5: Train mae: 0.51501	 val mae: 0.50182
# Epoch 6: Train mae: 0.49348	 val mae: 0.50817
# trigger times: 1
# Epoch 7: Train mae: 0.47129	 val mae: 0.46356
# Epoch 8: Train mae: 0.45817	 val mae: 0.44612
# Epoch 9: Train mae: 0.45344	 val mae: 0.48057
# trigger times: 1
# Epoch 10: Train mae: 0.43985	 val mae: 0.45110
# trigger times: 2
# Epoch 11: Train mae: 0.42932	 val mae: 0.42398
# Epoch 12: Train mae: 0.42179	 val mae: 0.40886
# Epoch 13: Train mae: 0.41756	 val mae: 0.40468
# Epoch 14: Train mae: 0.41481	 val mae: 0.46841
# trigger times: 1
# Epoch 15: Train mae: 0.40336	 val mae: 0.39287
# Epoch 16: Train mae: 0.39729	 val mae: 0.39378
# trigger times: 1
# Epoch 17: Train mae: 0.39516	 val mae: 0.38911
# Epoch 18: Train mae: 0.38547	 val mae: 0.38257
# Epoch 19: Train mae: 0.38545	 val mae: 0.38313
# trigger times: 1
# Epoch 20: Train mae: 0.37732	 val mae: 0.37273
# Epoch 21: Train mae: 0.37023	 val mae: 0.35969
# Epoch 22: Train mae: 0.36859	 val mae: 0.35633
# Epoch 23: Train mae: 0.36531	 val mae: 0.36847
# trigger times: 1
# Epoch 24: Train mae: 0.36466	 val mae: 0.36474
# trigger times: 2
# Epoch 25: Train mae: 0.35785	 val mae: 0.35091
# Epoch 26: Train mae: 0.35638	 val mae: 0.35161
# trigger times: 1
# Epoch 27: Train mae: 0.35359	 val mae: 0.35394
# trigger times: 2
# Epoch 28: Train mae: 0.34905	 val mae: 0.36134
# trigger times: 3
# Epoch 29: Train mae: 0.34898	 val mae: 0.34379
# Epoch 30: Train mae: 0.35186	 val mae: 0.34249
# Epoch 31: Train mae: 0.34785	 val mae: 0.34837
# trigger times: 1
# Epoch 32: Train mae: 0.34264	 val mae: 0.35119
# trigger times: 2
# Epoch 33: Train mae: 0.34519	 val mae: 0.35037
# trigger times: 3
# Epoch 34: Train mae: 0.34390	 val mae: 0.35497
# trigger times: 4
# Epoch 35: Train mae: 0.34604	 val mae: 0.34686
# trigger times: 5
# Epoch 36: Train mae: 0.34070	 val mae: 0.33914
# Epoch 37: Train mae: 0.33761	 val mae: 0.34086
# trigger times: 1
# Epoch 38: Train mae: 0.33777	 val mae: 0.33569
# Epoch 39: Train mae: 0.34279	 val mae: 0.33338
# Epoch 40: Train mae: 0.33358	 val mae: 0.34231
# trigger times: 1
# Epoch 41: Train mae: 0.33311	 val mae: 0.33459
# trigger times: 2
# Epoch 42: Train mae: 0.33317	 val mae: 0.33493
# trigger times: 3
# Epoch 43: Train mae: 0.33129	 val mae: 0.33221
# Epoch 44: Train mae: 0.33026	 val mae: 0.33656
# trigger times: 1
# Epoch 45: Train mae: 0.33078	 val mae: 0.33045
# Epoch 46: Train mae: 0.32789	 val mae: 0.33146
# trigger times: 1
# Epoch 47: Train mae: 0.32455	 val mae: 0.35137
# trigger times: 2
# Epoch 48: Train mae: 0.32338	 val mae: 0.34160
# trigger times: 3
# Epoch 49: Train mae: 0.32507	 val mae: 0.32975
# Epoch 50: Train mae: 0.32582	 val mae: 0.33461
# trigger times: 1
# Epoch 51: Train mae: 0.32328	 val mae: 0.33768
# trigger times: 2
# Epoch 52: Train mae: 0.32485	 val mae: 0.32636
# Epoch 53: Train mae: 0.32079	 val mae: 0.33484
# trigger times: 1
# Epoch 54: Train mae: 0.31970	 val mae: 0.34624
# trigger times: 2
# Epoch 55: Train mae: 0.31906	 val mae: 0.33152
# trigger times: 3
# Epoch 56: Train mae: 0.31790	 val mae: 0.32632
# Epoch 57: Train mae: 0.31498	 val mae: 0.34095
# trigger times: 1
# Epoch 58: Train mae: 0.31917	 val mae: 0.32397
# Epoch 59: Train mae: 0.31758	 val mae: 0.36372
# trigger times: 1
# Epoch 60: Train mae: 0.31732	 val mae: 0.32235
# Epoch 61: Train mae: 0.31099	 val mae: 0.32381
# trigger times: 1
# Epoch 62: Train mae: 0.31206	 val mae: 0.33096
# trigger times: 2
# Epoch 63: Train mae: 0.31349	 val mae: 0.35023
# trigger times: 3
# Epoch 64: Train mae: 0.31420	 val mae: 0.33446
# trigger times: 4
# Epoch 65: Train mae: 0.31134	 val mae: 0.32155
# Epoch 66: Train mae: 0.31009	 val mae: 0.32241
# trigger times: 1
# Epoch 67: Train mae: 0.30600	 val mae: 0.32214
# trigger times: 2
# Epoch 68: Train mae: 0.30645	 val mae: 0.32284
# trigger times: 3
# Epoch 69: Train mae: 0.30301	 val mae: 0.32361
# trigger times: 4
# Epoch 70: Train mae: 0.30080	 val mae: 0.32205
# trigger times: 5
# Epoch 71: Train mae: 0.30299	 val mae: 0.32233
# trigger times: 6
# Epoch 72: Train mae: 0.30141	 val mae: 0.31830
# Epoch 73: Train mae: 0.29858	 val mae: 0.31348
# Epoch 74: Train mae: 0.30041	 val mae: 0.31113
# Epoch 75: Train mae: 0.29691	 val mae: 0.31378
# trigger times: 1
# Epoch 76: Train mae: 0.29950	 val mae: 0.31221
# trigger times: 2
# Epoch 77: Train mae: 0.29801	 val mae: 0.31619
# trigger times: 3
# Epoch 78: Train mae: 0.29121	 val mae: 0.30808
# Epoch 79: Train mae: 0.29567	 val mae: 0.31259
# trigger times: 1
# Epoch 80: Train mae: 0.29382	 val mae: 0.31404
# trigger times: 2
# Epoch 81: Train mae: 0.28934	 val mae: 0.31117
# trigger times: 3
# Epoch 82: Train mae: 0.28792	 val mae: 0.31660
# trigger times: 4
# Epoch 83: Train mae: 0.28718	 val mae: 0.30966
# trigger times: 5
# Epoch 84: Train mae: 0.28995	 val mae: 0.33307
# trigger times: 6
# Epoch 85: Train mae: 0.28893	 val mae: 0.32419
# trigger times: 7
# Epoch 86: Train mae: 0.28760	 val mae: 0.30533
# Epoch 87: Train mae: 0.28473	 val mae: 0.30480
# Epoch 88: Train mae: 0.28708	 val mae: 0.30480
# Epoch 89: Train mae: 0.28486	 val mae: 0.29990
# Epoch 90: Train mae: 0.28075	 val mae: 0.30389
# trigger times: 1
# Epoch 91: Train mae: 0.27945	 val mae: 0.33041
# trigger times: 2
# Epoch 92: Train mae: 0.28071	 val mae: 0.30168
# trigger times: 3
# Epoch 93: Train mae: 0.28067	 val mae: 0.30391
# trigger times: 4
# Epoch 94: Train mae: 0.27726	 val mae: 0.30226
# trigger times: 5
# Epoch 95: Train mae: 0.27618	 val mae: 0.30141
# trigger times: 6
# Epoch 96: Train mae: 0.27891	 val mae: 0.29986
# Epoch 97: Train mae: 0.27705	 val mae: 0.29868
# Epoch 98: Train mae: 0.27476	 val mae: 0.31208
# trigger times: 1
# Epoch 99: Train mae: 0.27136	 val mae: 0.29851
# Epoch 100: Train mae: 0.26916	 val mae: 0.29203
# Epoch 101: Train mae: 0.27298	 val mae: 0.30548
# trigger times: 1
# Epoch 102: Train mae: 0.27060	 val mae: 0.30255
# trigger times: 2
# Epoch 103: Train mae: 0.26625	 val mae: 0.29961
# trigger times: 3
# Epoch 104: Train mae: 0.27193	 val mae: 0.29646
# trigger times: 4
# Epoch 105: Train mae: 0.26427	 val mae: 0.30121
# trigger times: 5
# Epoch 106: Train mae: 0.26514	 val mae: 0.29513
# trigger times: 6
# Epoch 107: Train mae: 0.26419	 val mae: 0.29056
# Epoch 108: Train mae: 0.26005	 val mae: 0.29665
# trigger times: 1
# Epoch 109: Train mae: 0.26065	 val mae: 0.29435
# trigger times: 2
# Epoch 110: Train mae: 0.26275	 val mae: 0.29017
# Epoch 111: Train mae: 0.26271	 val mae: 0.29830
# trigger times: 1
# Epoch 112: Train mae: 0.25727	 val mae: 0.29159
# trigger times: 2
# Epoch 113: Train mae: 0.25903	 val mae: 0.29845
# trigger times: 3
# Epoch 114: Train mae: 0.25846	 val mae: 0.29888
# trigger times: 4
# Epoch 115: Train mae: 0.25852	 val mae: 0.29363
# trigger times: 5
# Epoch 116: Train mae: 0.25826	 val mae: 0.29444
# trigger times: 6
# Epoch 117: Train mae: 0.25964	 val mae: 0.28776
# Epoch 118: Train mae: 0.25296	 val mae: 0.29315
# trigger times: 1
# Epoch 119: Train mae: 0.25413	 val mae: 0.29925
# trigger times: 2
# Epoch 120: Train mae: 0.25394	 val mae: 0.28728
# Epoch 121: Train mae: 0.25173	 val mae: 0.29021
# trigger times: 1
# Epoch 122: Train mae: 0.24891	 val mae: 0.28976
# trigger times: 2
# Epoch 123: Train mae: 0.25129	 val mae: 0.29148
# trigger times: 3
# Epoch 124: Train mae: 0.24850	 val mae: 0.29060
# trigger times: 4
# Epoch 125: Train mae: 0.24752	 val mae: 0.28989
# trigger times: 5
# Epoch 126: Train mae: 0.24942	 val mae: 0.29341
# trigger times: 6
# Epoch 127: Train mae: 0.25053	 val mae: 0.30262
# trigger times: 7
# Epoch 128: Train mae: 0.24892	 val mae: 0.29654
# trigger times: 8
# Epoch 129: Train mae: 0.24574	 val mae: 0.29227
# trigger times: 9
# Epoch 130: Train mae: 0.24551	 val mae: 0.30502
# trigger times: 10
# Epoch 131: Train mae: 0.24524	 val mae: 0.28651
# Epoch 132: Train mae: 0.24273	 val mae: 0.28587
# Epoch 133: Train mae: 0.24038	 val mae: 0.28391
# Epoch 134: Train mae: 0.24381	 val mae: 0.28504
# trigger times: 1
# Epoch 135: Train mae: 0.24338	 val mae: 0.29528
# trigger times: 2
# Epoch 136: Train mae: 0.24162	 val mae: 0.29076
# trigger times: 3
# Epoch 137: Train mae: 0.23684	 val mae: 0.28442
# trigger times: 4
# Epoch 138: Train mae: 0.23985	 val mae: 0.29252
# trigger times: 5
# Epoch 139: Train mae: 0.23837	 val mae: 0.28377
# Epoch 140: Train mae: 0.23871	 val mae: 0.28055
# Epoch 141: Train mae: 0.23595	 val mae: 0.28782
# trigger times: 1
# Epoch 142: Train mae: 0.23567	 val mae: 0.29396
# trigger times: 2
# Epoch 143: Train mae: 0.23394	 val mae: 0.28676
# trigger times: 3
# Epoch 144: Train mae: 0.23399	 val mae: 0.28294
# trigger times: 4
# Epoch 145: Train mae: 0.23430	 val mae: 0.28378
# trigger times: 5
# Epoch 146: Train mae: 0.23120	 val mae: 0.28407
# trigger times: 6
# Epoch 147: Train mae: 0.23100	 val mae: 0.28981
# trigger times: 7
# Epoch 148: Train mae: 0.23237	 val mae: 0.28092
# trigger times: 8
# Epoch 149: Train mae: 0.23049	 val mae: 0.28222
# trigger times: 9
# Epoch 150: Train mae: 0.22839	 val mae: 0.29044
# trigger times: 10
# Epoch 151: Train mae: 0.23003	 val mae: 0.28500
# trigger times: 11
# Epoch 152: Train mae: 0.22842	 val mae: 0.28231
# trigger times: 12
# Epoch 153: Train mae: 0.22440	 val mae: 0.28251
# trigger times: 13
# Epoch 154: Train mae: 0.22695	 val mae: 0.28187
# trigger times: 14
# Epoch 155: Train mae: 0.22699	 val mae: 0.28346
# trigger times: 15
# Epoch 156: Train mae: 0.22895	 val mae: 0.28522
# trigger times: 16
# Early stopping!
# Start to test process.
# Epoch 0: Train mae: 1.07786	 val mae: 0.73271
# Epoch 1: Train mae: 0.70423	 val mae: 0.63457
# Epoch 2: Train mae: 0.61307	 val mae: 0.56572
# Epoch 3: Train mae: 0.56186	 val mae: 0.55771
# Epoch 4: Train mae: 0.54187	 val mae: 0.50943
# Epoch 5: Train mae: 0.52113	 val mae: 0.49357
# Epoch 6: Train mae: 0.49972	 val mae: 0.47986
# Epoch 7: Train mae: 0.48988	 val mae: 0.52819
# trigger times: 1
# Epoch 8: Train mae: 0.48117	 val mae: 0.47557
# Epoch 9: Train mae: 0.46736	 val mae: 0.46193
# Epoch 10: Train mae: 0.45951	 val mae: 0.45901
# Epoch 11: Train mae: 0.46118	 val mae: 0.42632
# Epoch 12: Train mae: 0.44208	 val mae: 0.42349
# Epoch 13: Train mae: 0.43500	 val mae: 0.40767
# Epoch 14: Train mae: 0.42818	 val mae: 0.40922
# trigger times: 1
# Epoch 15: Train mae: 0.41941	 val mae: 0.41117
# trigger times: 2
# Epoch 16: Train mae: 0.41995	 val mae: 0.40269
# Epoch 17: Train mae: 0.40840	 val mae: 0.40515
# trigger times: 1
# Epoch 18: Train mae: 0.40420	 val mae: 0.39237
# Epoch 19: Train mae: 0.40211	 val mae: 0.41608
# trigger times: 1
# Epoch 20: Train mae: 0.40197	 val mae: 0.40904
# trigger times: 2
# Epoch 21: Train mae: 0.39277	 val mae: 0.39166
# Epoch 22: Train mae: 0.38455	 val mae: 0.37399
# Epoch 23: Train mae: 0.38470	 val mae: 0.38183
# trigger times: 1
# Epoch 24: Train mae: 0.38283	 val mae: 0.37302
# Epoch 25: Train mae: 0.37343	 val mae: 0.38930
# trigger times: 1
# Epoch 26: Train mae: 0.37421	 val mae: 0.38452
# trigger times: 2
# Epoch 27: Train mae: 0.36665	 val mae: 0.34950
# Epoch 28: Train mae: 0.36731	 val mae: 0.34344
# Epoch 29: Train mae: 0.36010	 val mae: 0.36941
# trigger times: 1
# Epoch 30: Train mae: 0.35385	 val mae: 0.37034
# trigger times: 2
# Epoch 31: Train mae: 0.35572	 val mae: 0.34193
# Epoch 32: Train mae: 0.35178	 val mae: 0.34413
# trigger times: 1
# Epoch 33: Train mae: 0.35581	 val mae: 0.33488
# Epoch 34: Train mae: 0.34956	 val mae: 0.34658
# trigger times: 1
# Epoch 35: Train mae: 0.34838	 val mae: 0.33998
# trigger times: 2
# Epoch 36: Train mae: 0.34299	 val mae: 0.34115
# trigger times: 3
# Epoch 37: Train mae: 0.34330	 val mae: 0.35719
# trigger times: 4
# Epoch 38: Train mae: 0.34546	 val mae: 0.33712
# trigger times: 5
# Epoch 39: Train mae: 0.33524	 val mae: 0.32984
# Epoch 40: Train mae: 0.34040	 val mae: 0.33754
# trigger times: 1
# Epoch 41: Train mae: 0.33552	 val mae: 0.33065
# trigger times: 2
# Epoch 42: Train mae: 0.33373	 val mae: 0.34027
# trigger times: 3
# Epoch 43: Train mae: 0.33097	 val mae: 0.33247
# trigger times: 4
# Epoch 44: Train mae: 0.33429	 val mae: 0.35773
# trigger times: 5
# Epoch 45: Train mae: 0.33069	 val mae: 0.32993
# trigger times: 6
# Epoch 46: Train mae: 0.33204	 val mae: 0.32339
# Epoch 47: Train mae: 0.32958	 val mae: 0.32676
# trigger times: 1
# Epoch 48: Train mae: 0.32571	 val mae: 0.33170
# trigger times: 2
# Epoch 49: Train mae: 0.32494	 val mae: 0.34505
# trigger times: 3
# Epoch 50: Train mae: 0.32764	 val mae: 0.32799
# trigger times: 4
# Epoch 51: Train mae: 0.32482	 val mae: 0.32278
# Epoch 52: Train mae: 0.32208	 val mae: 0.33621
# trigger times: 1
# Epoch 53: Train mae: 0.31960	 val mae: 0.32224
# Epoch 54: Train mae: 0.31527	 val mae: 0.31739
# Epoch 55: Train mae: 0.31660	 val mae: 0.34493
# trigger times: 1
# Epoch 56: Train mae: 0.32150	 val mae: 0.33988
# trigger times: 2
# Epoch 57: Train mae: 0.31741	 val mae: 0.31720
# Epoch 58: Train mae: 0.31397	 val mae: 0.31940
# trigger times: 1
# Epoch 59: Train mae: 0.30833	 val mae: 0.31922
# trigger times: 2
# Epoch 60: Train mae: 0.31148	 val mae: 0.31161
# Epoch 61: Train mae: 0.31009	 val mae: 0.31469
# trigger times: 1
# Epoch 62: Train mae: 0.30991	 val mae: 0.31315
# trigger times: 2
# Epoch 63: Train mae: 0.31114	 val mae: 0.30770
# Epoch 64: Train mae: 0.30642	 val mae: 0.31335
# trigger times: 1
# Epoch 65: Train mae: 0.30658	 val mae: 0.31040
# trigger times: 2
# Epoch 66: Train mae: 0.30804	 val mae: 0.31393
# trigger times: 3
# Epoch 67: Train mae: 0.30658	 val mae: 0.31034
# trigger times: 4
# Epoch 68: Train mae: 0.29927	 val mae: 0.31113
# trigger times: 5
# Epoch 69: Train mae: 0.29957	 val mae: 0.31307
# trigger times: 6
# Epoch 70: Train mae: 0.29987	 val mae: 0.30829
# trigger times: 7
# Epoch 71: Train mae: 0.30015	 val mae: 0.30716
# Epoch 72: Train mae: 0.30046	 val mae: 0.31422
# trigger times: 1
# Epoch 73: Train mae: 0.29724	 val mae: 0.31074
# trigger times: 2
# Epoch 74: Train mae: 0.29736	 val mae: 0.30096
# Epoch 75: Train mae: 0.29311	 val mae: 0.30620
# trigger times: 1
# Epoch 76: Train mae: 0.29508	 val mae: 0.30477
# trigger times: 2
# Epoch 77: Train mae: 0.29409	 val mae: 0.30920
# trigger times: 3
# Epoch 78: Train mae: 0.29330	 val mae: 0.30016
# Epoch 79: Train mae: 0.29251	 val mae: 0.30880
# trigger times: 1
# Epoch 80: Train mae: 0.29103	 val mae: 0.30125
# trigger times: 2
# Epoch 81: Train mae: 0.29028	 val mae: 0.30907
# trigger times: 3
# Epoch 82: Train mae: 0.29628	 val mae: 0.30535
# trigger times: 4
# Epoch 83: Train mae: 0.28895	 val mae: 0.30216
# trigger times: 5
# Epoch 84: Train mae: 0.28522	 val mae: 0.31549
# trigger times: 6
# Epoch 85: Train mae: 0.28541	 val mae: 0.29476
# Epoch 86: Train mae: 0.28342	 val mae: 0.30112
# trigger times: 1
# Epoch 87: Train mae: 0.28730	 val mae: 0.30393
# trigger times: 2
# Epoch 88: Train mae: 0.28556	 val mae: 0.29863
# trigger times: 3
# Epoch 89: Train mae: 0.28151	 val mae: 0.29736
# trigger times: 4
# Epoch 90: Train mae: 0.28202	 val mae: 0.29829
# trigger times: 5
# Epoch 91: Train mae: 0.28436	 val mae: 0.29315
# Epoch 92: Train mae: 0.28275	 val mae: 0.30166
# trigger times: 1
# Epoch 93: Train mae: 0.28030	 val mae: 0.30285
# trigger times: 2
# Epoch 94: Train mae: 0.27717	 val mae: 0.29618
# trigger times: 3
# Epoch 95: Train mae: 0.27790	 val mae: 0.28974
# Epoch 96: Train mae: 0.27708	 val mae: 0.30613
# trigger times: 1
# Epoch 97: Train mae: 0.27599	 val mae: 0.29113
# trigger times: 2
# Epoch 98: Train mae: 0.27519	 val mae: 0.29508
# trigger times: 3
# Epoch 99: Train mae: 0.27382	 val mae: 0.29898
# trigger times: 4
# Epoch 100: Train mae: 0.27385	 val mae: 0.29287
# trigger times: 5
# Epoch 101: Train mae: 0.27344	 val mae: 0.29330
# trigger times: 6
# Epoch 102: Train mae: 0.27095	 val mae: 0.28490
# Epoch 103: Train mae: 0.27066	 val mae: 0.29113
# trigger times: 1
# Epoch 104: Train mae: 0.27277	 val mae: 0.28451
# Epoch 105: Train mae: 0.27149	 val mae: 0.28588
# trigger times: 1
# Epoch 106: Train mae: 0.27063	 val mae: 0.28626
# trigger times: 2
# Epoch 107: Train mae: 0.26706	 val mae: 0.29900
# trigger times: 3
# Epoch 108: Train mae: 0.26724	 val mae: 0.29710
# trigger times: 4
# Epoch 109: Train mae: 0.26326	 val mae: 0.28408
# Epoch 110: Train mae: 0.26750	 val mae: 0.28203
# Epoch 111: Train mae: 0.26506	 val mae: 0.28960
# trigger times: 1
# Epoch 112: Train mae: 0.26507	 val mae: 0.28309
# trigger times: 2
# Epoch 113: Train mae: 0.26221	 val mae: 0.28959
# trigger times: 3
# Epoch 114: Train mae: 0.26479	 val mae: 0.28866
# trigger times: 4
# Epoch 115: Train mae: 0.26033	 val mae: 0.28388
# trigger times: 5
# Epoch 116: Train mae: 0.26172	 val mae: 0.27884
# Epoch 117: Train mae: 0.26311	 val mae: 0.29079
# trigger times: 1
# Epoch 118: Train mae: 0.26082	 val mae: 0.28236
# trigger times: 2
# Epoch 119: Train mae: 0.25894	 val mae: 0.28315
# trigger times: 3
# Epoch 120: Train mae: 0.25657	 val mae: 0.28637
# trigger times: 4
# Epoch 121: Train mae: 0.25719	 val mae: 0.28475
# trigger times: 5
# Epoch 122: Train mae: 0.25820	 val mae: 0.28166
# trigger times: 6
# Epoch 123: Train mae: 0.25335	 val mae: 0.28389
# trigger times: 7
# Epoch 124: Train mae: 0.25541	 val mae: 0.27795
# Epoch 125: Train mae: 0.25218	 val mae: 0.28238
# trigger times: 1
# Epoch 126: Train mae: 0.25436	 val mae: 0.29947
# trigger times: 2
# Epoch 127: Train mae: 0.25336	 val mae: 0.28566
# trigger times: 3
# Epoch 128: Train mae: 0.24935	 val mae: 0.27636
# Epoch 129: Train mae: 0.25006	 val mae: 0.28680
# trigger times: 1
# Epoch 130: Train mae: 0.25049	 val mae: 0.27816
# trigger times: 2
# Epoch 131: Train mae: 0.25052	 val mae: 0.27681
# trigger times: 3
# Epoch 132: Train mae: 0.25586	 val mae: 0.27650
# trigger times: 4
# Epoch 133: Train mae: 0.24620	 val mae: 0.27571
# Epoch 134: Train mae: 0.24704	 val mae: 0.29639
# trigger times: 1
# Epoch 135: Train mae: 0.24611	 val mae: 0.27886
# trigger times: 2
# Epoch 136: Train mae: 0.24844	 val mae: 0.27915
# trigger times: 3
# Epoch 137: Train mae: 0.24503	 val mae: 0.27263
# Epoch 138: Train mae: 0.24498	 val mae: 0.27440
# trigger times: 1
# Epoch 139: Train mae: 0.24546	 val mae: 0.27953
# trigger times: 2
# Epoch 140: Train mae: 0.24129	 val mae: 0.27286
# trigger times: 3
# Epoch 141: Train mae: 0.24483	 val mae: 0.28614
# trigger times: 4
# Epoch 142: Train mae: 0.24349	 val mae: 0.26896
# Epoch 143: Train mae: 0.24029	 val mae: 0.26836
# Epoch 144: Train mae: 0.24149	 val mae: 0.27585
# trigger times: 1
# Epoch 145: Train mae: 0.24289	 val mae: 0.28314
# trigger times: 2
# Epoch 146: Train mae: 0.23824	 val mae: 0.26790
# Epoch 147: Train mae: 0.23836	 val mae: 0.27586
# trigger times: 1
# Epoch 148: Train mae: 0.24010	 val mae: 0.28017
# trigger times: 2
# Epoch 149: Train mae: 0.23932	 val mae: 0.27045
# trigger times: 3
# Epoch 150: Train mae: 0.23777	 val mae: 0.26517
# Epoch 151: Train mae: 0.23567	 val mae: 0.28186
# trigger times: 1
# Epoch 152: Train mae: 0.23400	 val mae: 0.29108
# trigger times: 2
# Epoch 153: Train mae: 0.23460	 val mae: 0.27290
# trigger times: 3
# Epoch 154: Train mae: 0.23577	 val mae: 0.28136
# trigger times: 4
# Epoch 155: Train mae: 0.23349	 val mae: 0.27538
# trigger times: 5
# Epoch 156: Train mae: 0.23216	 val mae: 0.27215
# trigger times: 6
# Epoch 157: Train mae: 0.23032	 val mae: 0.27448
# trigger times: 7
# Epoch 158: Train mae: 0.23069	 val mae: 0.27614
# trigger times: 8
# Epoch 159: Train mae: 0.23036	 val mae: 0.26943
# trigger times: 9
# Epoch 160: Train mae: 0.23230	 val mae: 0.27354
# trigger times: 10
# Epoch 161: Train mae: 0.22794	 val mae: 0.26768
# trigger times: 11
# Epoch 162: Train mae: 0.22782	 val mae: 0.26473
# Epoch 163: Train mae: 0.22839	 val mae: 0.28105
# trigger times: 1
# Epoch 164: Train mae: 0.22719	 val mae: 0.27039
# trigger times: 2
# Epoch 165: Train mae: 0.22968	 val mae: 0.27990
# trigger times: 3
# Epoch 166: Train mae: 0.22610	 val mae: 0.26518
# trigger times: 4
# Epoch 167: Train mae: 0.22799	 val mae: 0.28708
# trigger times: 5
# Epoch 168: Train mae: 0.22554	 val mae: 0.26611
# trigger times: 6
# Epoch 169: Train mae: 0.22560	 val mae: 0.26658
# trigger times: 7
# Epoch 170: Train mae: 0.22417	 val mae: 0.28121
# trigger times: 8
# Epoch 171: Train mae: 0.22324	 val mae: 0.26581
# trigger times: 9
# Epoch 172: Train mae: 0.22259	 val mae: 0.27245
# trigger times: 10
# Epoch 173: Train mae: 0.22214	 val mae: 0.27252
# trigger times: 11
# Epoch 174: Train mae: 0.22475	 val mae: 0.27346
# trigger times: 12
# Epoch 175: Train mae: 0.22091	 val mae: 0.26946
# trigger times: 13
# Epoch 176: Train mae: 0.21901	 val mae: 0.26301
# Epoch 177: Train mae: 0.21836	 val mae: 0.27115
# trigger times: 1
# Epoch 178: Train mae: 0.21811	 val mae: 0.26747
# trigger times: 2
# Epoch 179: Train mae: 0.21868	 val mae: 0.26545
# trigger times: 3
# Epoch 180: Train mae: 0.21837	 val mae: 0.26727
# trigger times: 4
# Epoch 181: Train mae: 0.21596	 val mae: 0.28467
# trigger times: 5
# Epoch 182: Train mae: 0.21659	 val mae: 0.26611
# trigger times: 6
# Epoch 183: Train mae: 0.21307	 val mae: 0.27476
# trigger times: 7
# Epoch 184: Train mae: 0.21452	 val mae: 0.27349
# trigger times: 8
# Epoch 185: Train mae: 0.21285	 val mae: 0.26860
# trigger times: 9
# Epoch 186: Train mae: 0.21514	 val mae: 0.27565
# trigger times: 10
# Epoch 187: Train mae: 0.21465	 val mae: 0.26579
# trigger times: 11
# Epoch 188: Train mae: 0.21330	 val mae: 0.27552
# trigger times: 12
# Epoch 189: Train mae: 0.21004	 val mae: 0.26833
# trigger times: 13
# Epoch 190: Train mae: 0.21106	 val mae: 0.26688
# trigger times: 14
# Epoch 191: Train mae: 0.20981	 val mae: 0.26468
# trigger times: 15
# Epoch 192: Train mae: 0.21238	 val mae: 0.26972
# trigger times: 16
# Early stopping!
# Start to test process.
# Epoch 0: Train mae: 1.04001	 val mae: 0.71247
# Epoch 1: Train mae: 0.67955	 val mae: 0.58777
# Epoch 2: Train mae: 0.59229	 val mae: 0.55304
# Epoch 3: Train mae: 0.56355	 val mae: 0.52920
# Epoch 4: Train mae: 0.54060	 val mae: 0.53051
# trigger times: 1
# Epoch 5: Train mae: 0.52175	 val mae: 0.47283
# Epoch 6: Train mae: 0.50476	 val mae: 0.47511
# trigger times: 1
# Epoch 7: Train mae: 0.48851	 val mae: 0.44712
# Epoch 8: Train mae: 0.46970	 val mae: 0.43112
# Epoch 9: Train mae: 0.45763	 val mae: 0.42986
# Epoch 10: Train mae: 0.45321	 val mae: 0.43000
# trigger times: 1
# Epoch 11: Train mae: 0.44004	 val mae: 0.39879
# Epoch 12: Train mae: 0.43037	 val mae: 0.40907
# trigger times: 1
# Epoch 13: Train mae: 0.42396	 val mae: 0.40112
# trigger times: 2
# Epoch 14: Train mae: 0.42104	 val mae: 0.38901
# Epoch 15: Train mae: 0.41511	 val mae: 0.38970
# trigger times: 1
# Epoch 16: Train mae: 0.41494	 val mae: 0.40243
# trigger times: 2
# Epoch 17: Train mae: 0.40925	 val mae: 0.37544
# Epoch 18: Train mae: 0.40472	 val mae: 0.37332
# Epoch 19: Train mae: 0.40123	 val mae: 0.36334
# Epoch 20: Train mae: 0.39560	 val mae: 0.37265
# trigger times: 1
# Epoch 21: Train mae: 0.38957	 val mae: 0.35498
# Epoch 22: Train mae: 0.38789	 val mae: 0.35612
# trigger times: 1
# Epoch 23: Train mae: 0.38200	 val mae: 0.34661
# Epoch 24: Train mae: 0.37866	 val mae: 0.35406
# trigger times: 1
# Epoch 25: Train mae: 0.37229	 val mae: 0.34043
# Epoch 26: Train mae: 0.36703	 val mae: 0.35627
# trigger times: 1
# Epoch 27: Train mae: 0.37295	 val mae: 0.34492
# trigger times: 2
# Epoch 28: Train mae: 0.36739	 val mae: 0.33993
# Epoch 29: Train mae: 0.36634	 val mae: 0.35700
# trigger times: 1
# Epoch 30: Train mae: 0.36458	 val mae: 0.34633
# trigger times: 2
# Epoch 31: Train mae: 0.35746	 val mae: 0.35064
# trigger times: 3
# Epoch 32: Train mae: 0.35945	 val mae: 0.33537
# Epoch 33: Train mae: 0.35779	 val mae: 0.33398
# Epoch 34: Train mae: 0.35459	 val mae: 0.33693
# trigger times: 1
# Epoch 35: Train mae: 0.35216	 val mae: 0.34565
# trigger times: 2
# Epoch 36: Train mae: 0.34850	 val mae: 0.33417
# trigger times: 3
# Epoch 37: Train mae: 0.34945	 val mae: 0.32559
# Epoch 38: Train mae: 0.34683	 val mae: 0.32925
# trigger times: 1
# Epoch 39: Train mae: 0.34293	 val mae: 0.31894
# Epoch 40: Train mae: 0.33875	 val mae: 0.32377
# trigger times: 1
# Epoch 41: Train mae: 0.34018	 val mae: 0.32582
# trigger times: 2
# Epoch 42: Train mae: 0.33508	 val mae: 0.32217
# trigger times: 3
# Epoch 43: Train mae: 0.33807	 val mae: 0.31685
# Epoch 44: Train mae: 0.33251	 val mae: 0.32197
# trigger times: 1
# Epoch 45: Train mae: 0.33795	 val mae: 0.32301
# trigger times: 2
# Epoch 46: Train mae: 0.33356	 val mae: 0.32749
# trigger times: 3
# Epoch 47: Train mae: 0.33264	 val mae: 0.33004
# trigger times: 4
# Epoch 48: Train mae: 0.33067	 val mae: 0.31445
# Epoch 49: Train mae: 0.33270	 val mae: 0.30785
# Epoch 50: Train mae: 0.32608	 val mae: 0.33452
# trigger times: 1
# Epoch 51: Train mae: 0.33247	 val mae: 0.31306
# trigger times: 2
# Epoch 52: Train mae: 0.32680	 val mae: 0.33194
# trigger times: 3
# Epoch 53: Train mae: 0.32896	 val mae: 0.31400
# trigger times: 4
# Epoch 54: Train mae: 0.32335	 val mae: 0.30658
# Epoch 55: Train mae: 0.32236	 val mae: 0.31526
# trigger times: 1
# Epoch 56: Train mae: 0.31951	 val mae: 0.31192
# trigger times: 2
# Epoch 57: Train mae: 0.31825	 val mae: 0.30574
# Epoch 58: Train mae: 0.32181	 val mae: 0.31765
# trigger times: 1
# Epoch 59: Train mae: 0.31622	 val mae: 0.31173
# trigger times: 2
# Epoch 60: Train mae: 0.31709	 val mae: 0.30494
# Epoch 61: Train mae: 0.31438	 val mae: 0.32883
# trigger times: 1
# Epoch 62: Train mae: 0.31128	 val mae: 0.33201
# trigger times: 2
# Epoch 63: Train mae: 0.31067	 val mae: 0.30779
# trigger times: 3
# Epoch 64: Train mae: 0.31264	 val mae: 0.29718
# Epoch 65: Train mae: 0.31065	 val mae: 0.31346
# trigger times: 1
# Epoch 66: Train mae: 0.30653	 val mae: 0.30314
# trigger times: 2
# Epoch 67: Train mae: 0.30602	 val mae: 0.29824
# trigger times: 3
# Epoch 68: Train mae: 0.30446	 val mae: 0.29921
# trigger times: 4
# Epoch 69: Train mae: 0.30766	 val mae: 0.30045
# trigger times: 5
# Epoch 70: Train mae: 0.30146	 val mae: 0.30284
# trigger times: 6
# Epoch 71: Train mae: 0.30594	 val mae: 0.30823
# trigger times: 7
# Epoch 72: Train mae: 0.30185	 val mae: 0.30694
# trigger times: 8
# Epoch 73: Train mae: 0.30361	 val mae: 0.30537
# trigger times: 9
# Epoch 74: Train mae: 0.30108	 val mae: 0.29308
# Epoch 75: Train mae: 0.29839	 val mae: 0.29599
# trigger times: 1
# Epoch 76: Train mae: 0.29923	 val mae: 0.29456
# trigger times: 2
# Epoch 77: Train mae: 0.29514	 val mae: 0.29358
# trigger times: 3
# Epoch 78: Train mae: 0.29653	 val mae: 0.29914
# trigger times: 4
# Epoch 79: Train mae: 0.29533	 val mae: 0.29986
# trigger times: 5
# Epoch 80: Train mae: 0.29746	 val mae: 0.29034
# Epoch 81: Train mae: 0.28845	 val mae: 0.29277
# trigger times: 1
# Epoch 82: Train mae: 0.29114	 val mae: 0.29542
# trigger times: 2
# Epoch 83: Train mae: 0.29446	 val mae: 0.29085
# trigger times: 3
# Epoch 84: Train mae: 0.29083	 val mae: 0.29254
# trigger times: 4
# Epoch 85: Train mae: 0.29383	 val mae: 0.29464
# trigger times: 5
# Epoch 86: Train mae: 0.29085	 val mae: 0.29119
# trigger times: 6
# Epoch 87: Train mae: 0.28557	 val mae: 0.29233
# trigger times: 7
# Epoch 88: Train mae: 0.29218	 val mae: 0.29110
# trigger times: 8
# Epoch 89: Train mae: 0.29010	 val mae: 0.28881
# Epoch 90: Train mae: 0.28513	 val mae: 0.29701
# trigger times: 1
# Epoch 91: Train mae: 0.28197	 val mae: 0.28440
# Epoch 92: Train mae: 0.28574	 val mae: 0.28145
# Epoch 93: Train mae: 0.28322	 val mae: 0.29168
# trigger times: 1
# Epoch 94: Train mae: 0.28062	 val mae: 0.28569
# trigger times: 2
# Epoch 95: Train mae: 0.28225	 val mae: 0.29630
# trigger times: 3
# Epoch 96: Train mae: 0.28274	 val mae: 0.28960
# trigger times: 4
# Epoch 97: Train mae: 0.28333	 val mae: 0.28262
# trigger times: 5
# Epoch 98: Train mae: 0.27923	 val mae: 0.28347
# trigger times: 6
# Epoch 99: Train mae: 0.27670	 val mae: 0.28910
# trigger times: 7
# Epoch 100: Train mae: 0.27905	 val mae: 0.28906
# trigger times: 8
# Epoch 101: Train mae: 0.27568	 val mae: 0.29610
# trigger times: 9
# Epoch 102: Train mae: 0.27572	 val mae: 0.28345
# trigger times: 10
# Epoch 103: Train mae: 0.27448	 val mae: 0.30453
# trigger times: 11
# Epoch 104: Train mae: 0.27391	 val mae: 0.27844
# Epoch 105: Train mae: 0.27160	 val mae: 0.29539
# trigger times: 1
# Epoch 106: Train mae: 0.27222	 val mae: 0.28216
# trigger times: 2
# Epoch 107: Train mae: 0.27297	 val mae: 0.27967
# trigger times: 3
# Epoch 108: Train mae: 0.27037	 val mae: 0.28244
# trigger times: 4
# Epoch 109: Train mae: 0.26880	 val mae: 0.27618
# Epoch 110: Train mae: 0.26779	 val mae: 0.27885
# trigger times: 1
# Epoch 111: Train mae: 0.27124	 val mae: 0.28745
# trigger times: 2
# Epoch 112: Train mae: 0.26686	 val mae: 0.29074
# trigger times: 3
# Epoch 113: Train mae: 0.26694	 val mae: 0.27820
# trigger times: 4
# Epoch 114: Train mae: 0.26623	 val mae: 0.27587
# Epoch 115: Train mae: 0.26752	 val mae: 0.27359
# Epoch 116: Train mae: 0.26545	 val mae: 0.27657
# trigger times: 1
# Epoch 117: Train mae: 0.26228	 val mae: 0.27128
# Epoch 118: Train mae: 0.26280	 val mae: 0.27308
# trigger times: 1
# Epoch 119: Train mae: 0.26435	 val mae: 0.27263
# trigger times: 2
# Epoch 120: Train mae: 0.25879	 val mae: 0.27707
# trigger times: 3
# Epoch 121: Train mae: 0.26124	 val mae: 0.27824
# trigger times: 4
# Epoch 122: Train mae: 0.25923	 val mae: 0.27951
# trigger times: 5
# Epoch 123: Train mae: 0.25879	 val mae: 0.27858
# trigger times: 6
# Epoch 124: Train mae: 0.25798	 val mae: 0.27903
# trigger times: 7
# Epoch 125: Train mae: 0.25781	 val mae: 0.29327
# trigger times: 8
# Epoch 126: Train mae: 0.26103	 val mae: 0.27546
# trigger times: 9
# Epoch 127: Train mae: 0.24958	 val mae: 0.27234
# trigger times: 10
# Epoch 128: Train mae: 0.25903	 val mae: 0.27901
# trigger times: 11
# Epoch 129: Train mae: 0.25304	 val mae: 0.27482
# trigger times: 12
# Epoch 130: Train mae: 0.25582	 val mae: 0.27962
# trigger times: 13
# Epoch 131: Train mae: 0.25067	 val mae: 0.27006
# Epoch 132: Train mae: 0.25271	 val mae: 0.27140
# trigger times: 1
# Epoch 133: Train mae: 0.24978	 val mae: 0.26762
# Epoch 134: Train mae: 0.25036	 val mae: 0.26885
# trigger times: 1
# Epoch 135: Train mae: 0.25024	 val mae: 0.32319
# trigger times: 2
# Epoch 136: Train mae: 0.25311	 val mae: 0.27448
# trigger times: 3
# Epoch 137: Train mae: 0.25053	 val mae: 0.27066
# trigger times: 4
# Epoch 138: Train mae: 0.25009	 val mae: 0.27996
# trigger times: 5
# Epoch 139: Train mae: 0.24932	 val mae: 0.27892
# trigger times: 6
# Epoch 140: Train mae: 0.24599	 val mae: 0.27703
# trigger times: 7
# Epoch 141: Train mae: 0.24657	 val mae: 0.26520
# Epoch 142: Train mae: 0.24378	 val mae: 0.27598
# trigger times: 1
# Epoch 143: Train mae: 0.24432	 val mae: 0.26929
# trigger times: 2
# Epoch 144: Train mae: 0.24402	 val mae: 0.26947
# trigger times: 3
# Epoch 145: Train mae: 0.24266	 val mae: 0.26587
# trigger times: 4
# Epoch 146: Train mae: 0.24117	 val mae: 0.26566
# trigger times: 5
# Epoch 147: Train mae: 0.24071	 val mae: 0.27501
# trigger times: 6
# Epoch 148: Train mae: 0.24337	 val mae: 0.26419
# Epoch 149: Train mae: 0.24214	 val mae: 0.28907
# trigger times: 1
# Epoch 150: Train mae: 0.24150	 val mae: 0.26177
# Epoch 151: Train mae: 0.24032	 val mae: 0.26813
# trigger times: 1
# Epoch 152: Train mae: 0.23859	 val mae: 0.26893
# trigger times: 2
# Epoch 153: Train mae: 0.23618	 val mae: 0.25946
# Epoch 154: Train mae: 0.23460	 val mae: 0.26573
# trigger times: 1
# Epoch 155: Train mae: 0.23714	 val mae: 0.27319
# trigger times: 2
# Epoch 156: Train mae: 0.23848	 val mae: 0.27011
# trigger times: 3
# Epoch 157: Train mae: 0.23589	 val mae: 0.27643
# trigger times: 4
# Epoch 158: Train mae: 0.23476	 val mae: 0.26690
# trigger times: 5
# Epoch 159: Train mae: 0.23537	 val mae: 0.26000
# trigger times: 6
# Epoch 160: Train mae: 0.23725	 val mae: 0.26366
# trigger times: 7
# Epoch 161: Train mae: 0.23320	 val mae: 0.27108
# trigger times: 8
# Epoch 162: Train mae: 0.23131	 val mae: 0.26983
# trigger times: 9
# Epoch 163: Train mae: 0.23554	 val mae: 0.26338
# trigger times: 10
# Epoch 164: Train mae: 0.22845	 val mae: 0.26018
# trigger times: 11
# Epoch 165: Train mae: 0.23044	 val mae: 0.26392
# trigger times: 12
# Epoch 166: Train mae: 0.22909	 val mae: 0.25908
# Epoch 167: Train mae: 0.23048	 val mae: 0.26645
# trigger times: 1
# Epoch 168: Train mae: 0.22699	 val mae: 0.27022
# trigger times: 2
# Epoch 169: Train mae: 0.22670	 val mae: 0.25770
# Epoch 170: Train mae: 0.22511	 val mae: 0.26310
# trigger times: 1
# Epoch 171: Train mae: 0.22737	 val mae: 0.27144
# trigger times: 2
# Epoch 172: Train mae: 0.22703	 val mae: 0.26342
# trigger times: 3
# Epoch 173: Train mae: 0.22181	 val mae: 0.26848
# trigger times: 4
# Epoch 174: Train mae: 0.22324	 val mae: 0.25901
# trigger times: 5
# Epoch 175: Train mae: 0.22187	 val mae: 0.26059
# trigger times: 6
# Epoch 176: Train mae: 0.22285	 val mae: 0.26271
# trigger times: 7
# Epoch 177: Train mae: 0.22022	 val mae: 0.26328
# trigger times: 8
# Epoch 178: Train mae: 0.22179	 val mae: 0.26391
# trigger times: 9
# Epoch 179: Train mae: 0.22297	 val mae: 0.26413
# trigger times: 10
# Epoch 180: Train mae: 0.22172	 val mae: 0.26559
# trigger times: 11
# Epoch 181: Train mae: 0.21850	 val mae: 0.26468
# trigger times: 12
# Epoch 182: Train mae: 0.21616	 val mae: 0.25798
# trigger times: 13
# Epoch 183: Train mae: 0.21863	 val mae: 0.26503
# trigger times: 14
# Epoch 184: Train mae: 0.21772	 val mae: 0.25881
# trigger times: 15
# Epoch 185: Train mae: 0.21677	 val mae: 0.25714
# Epoch 186: Train mae: 0.21645	 val mae: 0.26330
# trigger times: 1
# Epoch 187: Train mae: 0.21531	 val mae: 0.28162
# trigger times: 2
# Epoch 188: Train mae: 0.21354	 val mae: 0.26214
# trigger times: 3
# Epoch 189: Train mae: 0.21154	 val mae: 0.25683
# Epoch 190: Train mae: 0.21272	 val mae: 0.25572
# Epoch 191: Train mae: 0.21276	 val mae: 0.25788
# trigger times: 1
# Epoch 192: Train mae: 0.20929	 val mae: 0.25794
# trigger times: 2
# Epoch 193: Train mae: 0.21344	 val mae: 0.26120
# trigger times: 3
# Epoch 194: Train mae: 0.21235	 val mae: 0.25877
# trigger times: 4
# Epoch 195: Train mae: 0.21248	 val mae: 0.26000
# trigger times: 5
# Epoch 196: Train mae: 0.20762	 val mae: 0.26259
# trigger times: 6
# Epoch 197: Train mae: 0.21039	 val mae: 0.25920
# trigger times: 7
# Epoch 198: Train mae: 0.20802	 val mae: 0.25894
# trigger times: 8
# Epoch 199: Train mae: 0.20787	 val mae: 0.26298
# trigger times: 9
# Epoch 200: Train mae: 0.20696	 val mae: 0.25803
# trigger times: 10
# Epoch 201: Train mae: 0.20685	 val mae: 0.25949
# trigger times: 11
# Epoch 202: Train mae: 0.20540	 val mae: 0.25900
# trigger times: 12
# Epoch 203: Train mae: 0.20447	 val mae: 0.25602
# trigger times: 13
# Epoch 204: Train mae: 0.20443	 val mae: 0.25588
# trigger times: 14
# Epoch 205: Train mae: 0.20449	 val mae: 0.28288
# trigger times: 15
# Epoch 206: Train mae: 0.20154	 val mae: 0.27972
# trigger times: 16
# Early stopping!
# Start to test process.
# Epoch 0: Train mae: 1.04433	 val mae: 0.70489
# Epoch 1: Train mae: 0.66974	 val mae: 0.60695
# Epoch 2: Train mae: 0.58826	 val mae: 0.54991
# Epoch 3: Train mae: 0.56577	 val mae: 0.52956
# Epoch 4: Train mae: 0.55340	 val mae: 0.50311
# Epoch 5: Train mae: 0.53818	 val mae: 0.48872
# Epoch 6: Train mae: 0.52096	 val mae: 0.46762
# Epoch 7: Train mae: 0.49723	 val mae: 0.45414
# Epoch 8: Train mae: 0.48040	 val mae: 0.44871
# Epoch 9: Train mae: 0.48179	 val mae: 0.45026
# trigger times: 1
# Epoch 10: Train mae: 0.46300	 val mae: 0.45387
# trigger times: 2
# Epoch 11: Train mae: 0.45402	 val mae: 0.42291
# Epoch 12: Train mae: 0.45586	 val mae: 0.47073
# trigger times: 1
# Epoch 13: Train mae: 0.44455	 val mae: 0.42021
# Epoch 14: Train mae: 0.44117	 val mae: 0.41182
# Epoch 15: Train mae: 0.42992	 val mae: 0.40270
# Epoch 16: Train mae: 0.43017	 val mae: 0.42887
# trigger times: 1
# Epoch 17: Train mae: 0.42037	 val mae: 0.39324
# Epoch 18: Train mae: 0.41387	 val mae: 0.40020
# trigger times: 1
# Epoch 19: Train mae: 0.40952	 val mae: 0.40165
# trigger times: 2
# Epoch 20: Train mae: 0.40641	 val mae: 0.37926
# Epoch 21: Train mae: 0.40121	 val mae: 0.39637
# trigger times: 1
# Epoch 22: Train mae: 0.39059	 val mae: 0.36402
# Epoch 23: Train mae: 0.39418	 val mae: 0.37247
# trigger times: 1
# Epoch 24: Train mae: 0.38828	 val mae: 0.35984
# Epoch 25: Train mae: 0.37965	 val mae: 0.35406
# Epoch 26: Train mae: 0.37793	 val mae: 0.34923
# Epoch 27: Train mae: 0.37488	 val mae: 0.34771
# Epoch 28: Train mae: 0.37074	 val mae: 0.33826
# Epoch 29: Train mae: 0.36366	 val mae: 0.34342
# trigger times: 1
# Epoch 30: Train mae: 0.37005	 val mae: 0.36881
# trigger times: 2
# Epoch 31: Train mae: 0.36404	 val mae: 0.33590
# Epoch 32: Train mae: 0.35805	 val mae: 0.33218
# Epoch 33: Train mae: 0.35503	 val mae: 0.34343
# trigger times: 1
# Epoch 34: Train mae: 0.35157	 val mae: 0.34134
# trigger times: 2
# Epoch 35: Train mae: 0.35371	 val mae: 0.33077
# Epoch 36: Train mae: 0.34896	 val mae: 0.33858
# trigger times: 1
# Epoch 37: Train mae: 0.34606	 val mae: 0.32241
# Epoch 38: Train mae: 0.34547	 val mae: 0.32291
# trigger times: 1
# Epoch 39: Train mae: 0.35003	 val mae: 0.31882
# Epoch 40: Train mae: 0.34477	 val mae: 0.35370
# trigger times: 1
# Epoch 41: Train mae: 0.35213	 val mae: 0.32055
# trigger times: 2
# Epoch 42: Train mae: 0.34205	 val mae: 0.33799
# trigger times: 3
# Epoch 43: Train mae: 0.33790	 val mae: 0.33814
# trigger times: 4
# Epoch 44: Train mae: 0.33787	 val mae: 0.32023
# trigger times: 5
# Epoch 45: Train mae: 0.33558	 val mae: 0.32373
# trigger times: 6
# Epoch 46: Train mae: 0.33449	 val mae: 0.33307
# trigger times: 7
# Epoch 47: Train mae: 0.33262	 val mae: 0.31397
# Epoch 48: Train mae: 0.33730	 val mae: 0.31470
# trigger times: 1
# Epoch 49: Train mae: 0.32840	 val mae: 0.31285
# Epoch 50: Train mae: 0.33095	 val mae: 0.30517
# Epoch 51: Train mae: 0.33076	 val mae: 0.31108
# trigger times: 1
# Epoch 52: Train mae: 0.32736	 val mae: 0.30373
# Epoch 53: Train mae: 0.32213	 val mae: 0.32382
# trigger times: 1
# Epoch 54: Train mae: 0.32505	 val mae: 0.31132
# trigger times: 2
# Epoch 55: Train mae: 0.32157	 val mae: 0.31196
# trigger times: 3
# Epoch 56: Train mae: 0.31783	 val mae: 0.31404
# trigger times: 4
# Epoch 57: Train mae: 0.31869	 val mae: 0.29919
# Epoch 58: Train mae: 0.32111	 val mae: 0.30828
# trigger times: 1
# Epoch 59: Train mae: 0.31348	 val mae: 0.30860
# trigger times: 2
# Epoch 60: Train mae: 0.31509	 val mae: 0.29881
# Epoch 61: Train mae: 0.31358	 val mae: 0.29692
# Epoch 62: Train mae: 0.30720	 val mae: 0.29384
# Epoch 63: Train mae: 0.31047	 val mae: 0.29461
# trigger times: 1
# Epoch 64: Train mae: 0.30534	 val mae: 0.29814
# trigger times: 2
# Epoch 65: Train mae: 0.30537	 val mae: 0.29672
# trigger times: 3
# Epoch 66: Train mae: 0.30473	 val mae: 0.29593
# trigger times: 4
# Epoch 67: Train mae: 0.30875	 val mae: 0.29776
# trigger times: 5
# Epoch 68: Train mae: 0.30194	 val mae: 0.29537
# trigger times: 6
# Epoch 69: Train mae: 0.30370	 val mae: 0.29146
# Epoch 70: Train mae: 0.30057	 val mae: 0.29290
# trigger times: 1
# Epoch 71: Train mae: 0.30026	 val mae: 0.28824
# Epoch 72: Train mae: 0.29767	 val mae: 0.29250
# trigger times: 1
# Epoch 73: Train mae: 0.30234	 val mae: 0.28879
# trigger times: 2
# Epoch 74: Train mae: 0.29214	 val mae: 0.29978
# trigger times: 3
# Epoch 75: Train mae: 0.29400	 val mae: 0.29274
# trigger times: 4
# Epoch 76: Train mae: 0.29041	 val mae: 0.28972
# trigger times: 5
# Epoch 77: Train mae: 0.29388	 val mae: 0.28266
# Epoch 78: Train mae: 0.29164	 val mae: 0.28559
# trigger times: 1
# Epoch 79: Train mae: 0.29118	 val mae: 0.28410
# trigger times: 2
# Epoch 80: Train mae: 0.28996	 val mae: 0.28821
# trigger times: 3
# Epoch 81: Train mae: 0.28666	 val mae: 0.29200
# trigger times: 4
# Epoch 82: Train mae: 0.28645	 val mae: 0.28725
# trigger times: 5
# Epoch 83: Train mae: 0.28332	 val mae: 0.28262
# Epoch 84: Train mae: 0.28237	 val mae: 0.28751
# trigger times: 1
# Epoch 85: Train mae: 0.28094	 val mae: 0.30200
# trigger times: 2
# Epoch 86: Train mae: 0.28520	 val mae: 0.28910
# trigger times: 3
# Epoch 87: Train mae: 0.28068	 val mae: 0.27756
# Epoch 88: Train mae: 0.28026	 val mae: 0.28652
# trigger times: 1
# Epoch 89: Train mae: 0.27896	 val mae: 0.29202
# trigger times: 2
# Epoch 90: Train mae: 0.27930	 val mae: 0.29236
# trigger times: 3
# Epoch 91: Train mae: 0.27889	 val mae: 0.29879
# trigger times: 4
# Epoch 92: Train mae: 0.27806	 val mae: 0.29592
# trigger times: 5
# Epoch 93: Train mae: 0.27382	 val mae: 0.29149
# trigger times: 6
# Epoch 94: Train mae: 0.27520	 val mae: 0.28103
# trigger times: 7
# Epoch 95: Train mae: 0.27399	 val mae: 0.27895
# trigger times: 8
# Epoch 96: Train mae: 0.26959	 val mae: 0.27699
# Epoch 97: Train mae: 0.26940	 val mae: 0.27875
# trigger times: 1
# Epoch 98: Train mae: 0.27236	 val mae: 0.27920
# trigger times: 2
# Epoch 99: Train mae: 0.26922	 val mae: 0.27885
# trigger times: 3
# Epoch 100: Train mae: 0.26772	 val mae: 0.28985
# trigger times: 4
# Epoch 101: Train mae: 0.26750	 val mae: 0.27969
# trigger times: 5
# Epoch 102: Train mae: 0.26733	 val mae: 0.27947
# trigger times: 6
# Epoch 103: Train mae: 0.26488	 val mae: 0.27531
# Epoch 104: Train mae: 0.26560	 val mae: 0.29438
# trigger times: 1
# Epoch 105: Train mae: 0.26530	 val mae: 0.27674
# trigger times: 2
# Epoch 106: Train mae: 0.26220	 val mae: 0.27531
# Epoch 107: Train mae: 0.26211	 val mae: 0.27671
# trigger times: 1
# Epoch 108: Train mae: 0.26250	 val mae: 0.27921
# trigger times: 2
# Epoch 109: Train mae: 0.26339	 val mae: 0.28641
# trigger times: 3
# Epoch 110: Train mae: 0.26244	 val mae: 0.27259
# Epoch 111: Train mae: 0.26242	 val mae: 0.27189
# Epoch 112: Train mae: 0.25692	 val mae: 0.28778
# trigger times: 1
# Epoch 113: Train mae: 0.25872	 val mae: 0.27914
# trigger times: 2
# Epoch 114: Train mae: 0.26486	 val mae: 0.27512
# trigger times: 3
# Epoch 115: Train mae: 0.25730	 val mae: 0.27128
# Epoch 116: Train mae: 0.25612	 val mae: 0.30664
# trigger times: 1
# Epoch 117: Train mae: 0.25824	 val mae: 0.27052
# Epoch 118: Train mae: 0.25221	 val mae: 0.27082
# trigger times: 1
# Epoch 119: Train mae: 0.25361	 val mae: 0.27626
# trigger times: 2
# Epoch 120: Train mae: 0.25242	 val mae: 0.28061
# trigger times: 3
# Epoch 121: Train mae: 0.25194	 val mae: 0.28150
# trigger times: 4
# Epoch 122: Train mae: 0.24891	 val mae: 0.27387
# trigger times: 5
# Epoch 123: Train mae: 0.25060	 val mae: 0.27736
# trigger times: 6
# Epoch 124: Train mae: 0.25053	 val mae: 0.27869
# trigger times: 7
# Epoch 125: Train mae: 0.24981	 val mae: 0.28470
# trigger times: 8
# Epoch 126: Train mae: 0.24772	 val mae: 0.27583
# trigger times: 9
# Epoch 127: Train mae: 0.24394	 val mae: 0.26911
# Epoch 128: Train mae: 0.24661	 val mae: 0.27276
# trigger times: 1
# Epoch 129: Train mae: 0.24348	 val mae: 0.27991
# trigger times: 2
# Epoch 130: Train mae: 0.24673	 val mae: 0.27782
# trigger times: 3
# Epoch 131: Train mae: 0.24476	 val mae: 0.27108
# trigger times: 4
# Epoch 132: Train mae: 0.24370	 val mae: 0.27188
# trigger times: 5
# Epoch 133: Train mae: 0.24526	 val mae: 0.26801
# Epoch 134: Train mae: 0.24159	 val mae: 0.27059
# trigger times: 1
# Epoch 135: Train mae: 0.24203	 val mae: 0.28327
# trigger times: 2
# Epoch 136: Train mae: 0.24177	 val mae: 0.27756
# trigger times: 3
# Epoch 137: Train mae: 0.24125	 val mae: 0.28899
# trigger times: 4
# Epoch 138: Train mae: 0.24507	 val mae: 0.26991
# trigger times: 5
# Epoch 139: Train mae: 0.24063	 val mae: 0.27211
# trigger times: 6
# Epoch 140: Train mae: 0.23543	 val mae: 0.27136
# trigger times: 7
# Epoch 141: Train mae: 0.23694	 val mae: 0.26887
# trigger times: 8
# Epoch 142: Train mae: 0.23664	 val mae: 0.27611
# trigger times: 9
# Epoch 143: Train mae: 0.23523	 val mae: 0.27106
# trigger times: 10
# Epoch 144: Train mae: 0.23432	 val mae: 0.28059
# trigger times: 11
# Epoch 145: Train mae: 0.23623	 val mae: 0.27071
# trigger times: 12
# Epoch 146: Train mae: 0.23139	 val mae: 0.27530
# trigger times: 13
# Epoch 147: Train mae: 0.23026	 val mae: 0.26907
# trigger times: 14
# Epoch 148: Train mae: 0.23229	 val mae: 0.26828
# trigger times: 15
# Epoch 149: Train mae: 0.23034	 val mae: 0.27365
# trigger times: 16
# Early stopping!
# Start to test process.
# Epoch 0: Train mae: 1.05486	 val mae: 0.71293
# Epoch 1: Train mae: 0.65152	 val mae: 0.62200
# Epoch 2: Train mae: 0.60039	 val mae: 0.57672
# Epoch 3: Train mae: 0.57456	 val mae: 0.55807
# Epoch 4: Train mae: 0.55060	 val mae: 0.55508
# Epoch 5: Train mae: 0.53826	 val mae: 0.51043
# Epoch 6: Train mae: 0.52029	 val mae: 0.49158
# Epoch 7: Train mae: 0.49927	 val mae: 0.48242
# Epoch 8: Train mae: 0.48325	 val mae: 0.46980
# Epoch 9: Train mae: 0.48031	 val mae: 0.46584
# Epoch 10: Train mae: 0.46545	 val mae: 0.45750
# Epoch 11: Train mae: 0.46224	 val mae: 0.45128
# Epoch 12: Train mae: 0.45840	 val mae: 0.44490
# Epoch 13: Train mae: 0.45027	 val mae: 0.45003
# trigger times: 1
# Epoch 14: Train mae: 0.44223	 val mae: 0.44595
# trigger times: 2
# Epoch 15: Train mae: 0.44055	 val mae: 0.42428
# Epoch 16: Train mae: 0.43279	 val mae: 0.43078
# trigger times: 1
# Epoch 17: Train mae: 0.42873	 val mae: 0.42895
# trigger times: 2
# Epoch 18: Train mae: 0.42657	 val mae: 0.42444
# trigger times: 3
# Epoch 19: Train mae: 0.41799	 val mae: 0.42338
# Epoch 20: Train mae: 0.41137	 val mae: 0.42758
# trigger times: 1
# Epoch 21: Train mae: 0.41063	 val mae: 0.40933
# Epoch 22: Train mae: 0.40453	 val mae: 0.40186
# Epoch 23: Train mae: 0.39699	 val mae: 0.39076
# Epoch 24: Train mae: 0.39653	 val mae: 0.37627
# Epoch 25: Train mae: 0.38842	 val mae: 0.40338
# trigger times: 1
# Epoch 26: Train mae: 0.38452	 val mae: 0.37415
# Epoch 27: Train mae: 0.38191	 val mae: 0.36904
# Epoch 28: Train mae: 0.37540	 val mae: 0.36628
# Epoch 29: Train mae: 0.37791	 val mae: 0.35930
# Epoch 30: Train mae: 0.36698	 val mae: 0.35685
# Epoch 31: Train mae: 0.36437	 val mae: 0.36078
# trigger times: 1
# Epoch 32: Train mae: 0.36557	 val mae: 0.38352
# trigger times: 2
# Epoch 33: Train mae: 0.36609	 val mae: 0.36465
# trigger times: 3
# Epoch 34: Train mae: 0.36193	 val mae: 0.35726
# trigger times: 4
# Epoch 35: Train mae: 0.35614	 val mae: 0.35454
# Epoch 36: Train mae: 0.35440	 val mae: 0.36080
# trigger times: 1
# Epoch 37: Train mae: 0.35185	 val mae: 0.37365
# trigger times: 2
# Epoch 38: Train mae: 0.35354	 val mae: 0.34633
# Epoch 39: Train mae: 0.34882	 val mae: 0.34181
# Epoch 40: Train mae: 0.34550	 val mae: 0.34159
# Epoch 41: Train mae: 0.34639	 val mae: 0.35168
# trigger times: 1
# Epoch 42: Train mae: 0.33878	 val mae: 0.33874
# Epoch 43: Train mae: 0.34499	 val mae: 0.33603
# Epoch 44: Train mae: 0.34433	 val mae: 0.34342
# trigger times: 1
# Epoch 45: Train mae: 0.33845	 val mae: 0.33744
# trigger times: 2
# Epoch 46: Train mae: 0.33426	 val mae: 0.36261
# trigger times: 3
# Epoch 47: Train mae: 0.33539	 val mae: 0.33638
# trigger times: 4
# Epoch 48: Train mae: 0.33603	 val mae: 0.33254
# Epoch 49: Train mae: 0.33684	 val mae: 0.33494
# trigger times: 1
# Epoch 50: Train mae: 0.33686	 val mae: 0.34980
# trigger times: 2
# Epoch 51: Train mae: 0.33241	 val mae: 0.32674
# Epoch 52: Train mae: 0.33036	 val mae: 0.34170
# trigger times: 1
# Epoch 53: Train mae: 0.33175	 val mae: 0.33536
# trigger times: 2
# Epoch 54: Train mae: 0.33132	 val mae: 0.32612
# Epoch 55: Train mae: 0.32652	 val mae: 0.32608
# Epoch 56: Train mae: 0.32546	 val mae: 0.32796
# trigger times: 1
# Epoch 57: Train mae: 0.32611	 val mae: 0.32050
# Epoch 58: Train mae: 0.32237	 val mae: 0.33158
# trigger times: 1
# Epoch 59: Train mae: 0.31992	 val mae: 0.32066
# trigger times: 2
# Epoch 60: Train mae: 0.31938	 val mae: 0.32356
# trigger times: 3
# Epoch 61: Train mae: 0.31729	 val mae: 0.31802
# Epoch 62: Train mae: 0.31932	 val mae: 0.33144
# trigger times: 1
# Epoch 63: Train mae: 0.31747	 val mae: 0.33084
# trigger times: 2
# Epoch 64: Train mae: 0.31888	 val mae: 0.33301
# trigger times: 3
# Epoch 65: Train mae: 0.31271	 val mae: 0.33300
# trigger times: 4
# Epoch 66: Train mae: 0.31481	 val mae: 0.31999
# trigger times: 5
# Epoch 67: Train mae: 0.31317	 val mae: 0.31521
# Epoch 68: Train mae: 0.31025	 val mae: 0.31190
# Epoch 69: Train mae: 0.31191	 val mae: 0.32305
# trigger times: 1
# Epoch 70: Train mae: 0.30583	 val mae: 0.31077
# Epoch 71: Train mae: 0.31030	 val mae: 0.31566
# trigger times: 1
# Epoch 72: Train mae: 0.30531	 val mae: 0.32500
# trigger times: 2
# Epoch 73: Train mae: 0.30841	 val mae: 0.30834
# Epoch 74: Train mae: 0.30792	 val mae: 0.31063
# trigger times: 1
# Epoch 75: Train mae: 0.30351	 val mae: 0.30490
# Epoch 76: Train mae: 0.29928	 val mae: 0.30700
# trigger times: 1
# Epoch 77: Train mae: 0.30219	 val mae: 0.30915
# trigger times: 2
# Epoch 78: Train mae: 0.29870	 val mae: 0.30453
# Epoch 79: Train mae: 0.29803	 val mae: 0.31230
# trigger times: 1
# Epoch 80: Train mae: 0.29824	 val mae: 0.30597
# trigger times: 2
# Epoch 81: Train mae: 0.29795	 val mae: 0.30715
# trigger times: 3
# Epoch 82: Train mae: 0.29471	 val mae: 0.30369
# Epoch 83: Train mae: 0.29541	 val mae: 0.30565
# trigger times: 1
# Epoch 84: Train mae: 0.29522	 val mae: 0.29617
# Epoch 85: Train mae: 0.29256	 val mae: 0.30471
# trigger times: 1
# Epoch 86: Train mae: 0.29232	 val mae: 0.29552
# Epoch 87: Train mae: 0.29111	 val mae: 0.30514
# trigger times: 1
# Epoch 88: Train mae: 0.28865	 val mae: 0.29826
# trigger times: 2
# Epoch 89: Train mae: 0.28582	 val mae: 0.29212
# Epoch 90: Train mae: 0.28787	 val mae: 0.29935
# trigger times: 1
# Epoch 91: Train mae: 0.28666	 val mae: 0.29745
# trigger times: 2
# Epoch 92: Train mae: 0.28692	 val mae: 0.30919
# trigger times: 3
# Epoch 93: Train mae: 0.28328	 val mae: 0.29508
# trigger times: 4
# Epoch 94: Train mae: 0.28501	 val mae: 0.29107
# Epoch 95: Train mae: 0.28403	 val mae: 0.29762
# trigger times: 1
# Epoch 96: Train mae: 0.28085	 val mae: 0.30291
# trigger times: 2
# Epoch 97: Train mae: 0.28253	 val mae: 0.29631
# trigger times: 3
# Epoch 98: Train mae: 0.27708	 val mae: 0.29579
# trigger times: 4
# Epoch 99: Train mae: 0.28086	 val mae: 0.30527
# trigger times: 5
# Epoch 100: Train mae: 0.27566	 val mae: 0.28651
# Epoch 101: Train mae: 0.27473	 val mae: 0.28642
# Epoch 102: Train mae: 0.27065	 val mae: 0.29055
# trigger times: 1
# Epoch 103: Train mae: 0.27178	 val mae: 0.29204
# trigger times: 2
# Epoch 104: Train mae: 0.27205	 val mae: 0.29652
# trigger times: 3
# Epoch 105: Train mae: 0.27045	 val mae: 0.28344
# Epoch 106: Train mae: 0.26981	 val mae: 0.29617
# trigger times: 1
# Epoch 107: Train mae: 0.26869	 val mae: 0.29368
# trigger times: 2
# Epoch 108: Train mae: 0.27037	 val mae: 0.28825
# trigger times: 3
# Epoch 109: Train mae: 0.26785	 val mae: 0.28812
# trigger times: 4
# Epoch 110: Train mae: 0.26513	 val mae: 0.28682
# trigger times: 5
# Epoch 111: Train mae: 0.26766	 val mae: 0.28449
# trigger times: 6
# Epoch 112: Train mae: 0.26256	 val mae: 0.28221
# Epoch 113: Train mae: 0.26489	 val mae: 0.28637
# trigger times: 1
# Epoch 114: Train mae: 0.26062	 val mae: 0.28366
# trigger times: 2
# Epoch 115: Train mae: 0.26048	 val mae: 0.28343
# trigger times: 3
# Epoch 116: Train mae: 0.25891	 val mae: 0.28775
# trigger times: 4
# Epoch 117: Train mae: 0.26025	 val mae: 0.31612
# trigger times: 5
# Epoch 118: Train mae: 0.26020	 val mae: 0.27917
# Epoch 119: Train mae: 0.25824	 val mae: 0.28249
# trigger times: 1
# Epoch 120: Train mae: 0.25684	 val mae: 0.28232
# trigger times: 2
# Epoch 121: Train mae: 0.25223	 val mae: 0.27997
# trigger times: 3
# Epoch 122: Train mae: 0.25516	 val mae: 0.30045
# trigger times: 4
# Epoch 123: Train mae: 0.25212	 val mae: 0.28903
# trigger times: 5
# Epoch 124: Train mae: 0.25405	 val mae: 0.28079
# trigger times: 6
# Epoch 125: Train mae: 0.25231	 val mae: 0.28057
# trigger times: 7
# Epoch 126: Train mae: 0.25219	 val mae: 0.28031
# trigger times: 8
# Epoch 127: Train mae: 0.25173	 val mae: 0.27970
# trigger times: 9
# Epoch 128: Train mae: 0.25062	 val mae: 0.27458
# Epoch 129: Train mae: 0.24702	 val mae: 0.27832
# trigger times: 1
# Epoch 130: Train mae: 0.24534	 val mae: 0.28128
# trigger times: 2
# Epoch 131: Train mae: 0.24962	 val mae: 0.29136
# trigger times: 3
# Epoch 132: Train mae: 0.24743	 val mae: 0.27782
# trigger times: 4
# Epoch 133: Train mae: 0.24729	 val mae: 0.27750
# trigger times: 5
# Epoch 134: Train mae: 0.24538	 val mae: 0.27643
# trigger times: 6
# Epoch 135: Train mae: 0.24561	 val mae: 0.27505
# trigger times: 7
# Epoch 136: Train mae: 0.24738	 val mae: 0.27491
# trigger times: 8
# Epoch 137: Train mae: 0.24211	 val mae: 0.27388
# Epoch 138: Train mae: 0.24088	 val mae: 0.27731
# trigger times: 1
# Epoch 139: Train mae: 0.24164	 val mae: 0.27473
# trigger times: 2
# Epoch 140: Train mae: 0.24374	 val mae: 0.28658
# trigger times: 3
# Epoch 141: Train mae: 0.24149	 val mae: 0.27448
# trigger times: 4
# Epoch 142: Train mae: 0.24118	 val mae: 0.27536
# trigger times: 5
# Epoch 143: Train mae: 0.23639	 val mae: 0.27415
# trigger times: 6
# Epoch 144: Train mae: 0.23622	 val mae: 0.28231
# trigger times: 7
# Epoch 145: Train mae: 0.23926	 val mae: 0.27584
# trigger times: 8
# Epoch 146: Train mae: 0.24186	 val mae: 0.27702
# trigger times: 9
# Epoch 147: Train mae: 0.23708	 val mae: 0.27728
# trigger times: 10
# Epoch 148: Train mae: 0.23747	 val mae: 0.27606
# trigger times: 11
# Epoch 149: Train mae: 0.23306	 val mae: 0.27541
# trigger times: 12
# Epoch 150: Train mae: 0.23084	 val mae: 0.27587
# trigger times: 13
# Epoch 151: Train mae: 0.23331	 val mae: 0.27300
# Epoch 152: Train mae: 0.23049	 val mae: 0.26867
# Epoch 153: Train mae: 0.22864	 val mae: 0.26809
# Epoch 154: Train mae: 0.23086	 val mae: 0.28551
# trigger times: 1
# Epoch 155: Train mae: 0.23349	 val mae: 0.27771
# trigger times: 2
# Epoch 156: Train mae: 0.23178	 val mae: 0.27973
# trigger times: 3
# Epoch 157: Train mae: 0.23044	 val mae: 0.27240
# trigger times: 4
# Epoch 158: Train mae: 0.22867	 val mae: 0.27837
# trigger times: 5
# Epoch 159: Train mae: 0.22750	 val mae: 0.27268
# trigger times: 6
# Epoch 160: Train mae: 0.22770	 val mae: 0.27896
# trigger times: 7
# Epoch 161: Train mae: 0.22558	 val mae: 0.28224
# trigger times: 8
# Epoch 162: Train mae: 0.22681	 val mae: 0.27902
# trigger times: 9
# Epoch 163: Train mae: 0.22758	 val mae: 0.26940
# trigger times: 10
# Epoch 164: Train mae: 0.22596	 val mae: 0.26503
# Epoch 165: Train mae: 0.22223	 val mae: 0.26749
# trigger times: 1
# Epoch 166: Train mae: 0.22267	 val mae: 0.28041
# trigger times: 2
# Epoch 167: Train mae: 0.22550	 val mae: 0.27437
# trigger times: 3
# Epoch 168: Train mae: 0.22400	 val mae: 0.28754
# trigger times: 4
# Epoch 169: Train mae: 0.22025	 val mae: 0.27147
# trigger times: 5
# Epoch 170: Train mae: 0.21829	 val mae: 0.27568
# trigger times: 6
# Epoch 171: Train mae: 0.21760	 val mae: 0.27484
# trigger times: 7
# Epoch 172: Train mae: 0.21881	 val mae: 0.26804
# trigger times: 8
# Epoch 173: Train mae: 0.21686	 val mae: 0.27755
# trigger times: 9
# Epoch 174: Train mae: 0.21441	 val mae: 0.27028
# trigger times: 10
# Epoch 175: Train mae: 0.21381	 val mae: 0.27265
# trigger times: 11
# Epoch 176: Train mae: 0.21710	 val mae: 0.27140
# trigger times: 12
# Epoch 177: Train mae: 0.21268	 val mae: 0.26818
# trigger times: 13
# Epoch 178: Train mae: 0.21338	 val mae: 0.28310
# trigger times: 14
# Epoch 179: Train mae: 0.21408	 val mae: 0.27215
# trigger times: 15
# Epoch 180: Train mae: 0.21283	 val mae: 0.27857
# trigger times: 16
# Early stopping!
# Start to test process.

# %%
format_float = "{:.2f}".format(best_mae)

# %%
type(format_float)
# Out:
# str

# %%
resSt = results[0][1]

# %%
res_val = resSt[2]

# %%
res_val
# Out:
# 0.6113349795341492

# %%
folds = 5
for fold in range(folds):
    train_loss_arr = []
    test_loss_arr = []
    for res in results[fold]:
        train_loss_arr.append(res[1])
        test_loss_arr.append(res[2])
        
    print(len(train_loss_arr))
    print(len(test_loss_arr))
    ax = plt.subplot(1,1,1)
    
    ax.WindowState = 'maximized';

    format_mae = "{:.2f}".format(best_mae_arr[fold])
    
  #  ax.plot([e for e in range(1,len(train_loss_arr) + 1)], train_loss_arr, label="train_loss")
    ax.plot([e for e in range(1,len(test_loss_arr) + 1)],
            test_loss_arr, label="Fold " + str(fold) + " (MAE = " + format_mae + ")")
    plt.xlabel("epoch")
    ax.title.set_text('5-Fold Validation')
    ax.legend()
    ax.figure.savefig('Visualization/'+str(fold)+'.png')
# Out:
# 157
# 157
# 193
# 193
# 207
# 207
# 150
# 150
# 181
# 181
# /home/arslan/anaconda3/envs/band/lib/python3.6/site-packages/ipykernel_launcher.py:11: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   # This is added back by InteractiveShellApp.init_path()

# %%
train_loss_arr
