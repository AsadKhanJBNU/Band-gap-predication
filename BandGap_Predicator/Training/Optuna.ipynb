# %%
import pandas as pd
import numpy as np

from rdkit import Chem
from rdkit.Chem import Draw
import networkx as nx
from torch_geometric.datasets import MoleculeNet
import matplotlib.pyplot as plt

import torch
import os
import pandas as pd
import numpy as np
import json,pickle
from collections import OrderedDict
from rdkit import Chem
from rdkit.Chem import MolFromSmiles
import networkx as nx

from torch_geometric.data import InMemoryDataset, Data
from torch_geometric.loader import DataLoader
from torch_geometric import torch_geometric
from sklearn.model_selection import train_test_split
from tqdm.notebook import tqdm
import torch
import torch.nn as nn

import Data_Preprocessing.Graph_Data as gd
from Data_Preprocessing.Graph_Data import Molecule_data
from models.AttentiveFPModel import AttentiveFP

# %%
df = pd.read_csv('Data_Preprocessing/omdb_smile_data_set.csv')

# %%
smiles = df['SMILE']
codIds = df['CODID']
band_gap = df['bgs']

# %%
X_train, X_val, y_train, y_val = train_test_split(smiles, band_gap, test_size=0.2)
y_train = y_train.to_numpy()
y_val = y_val.to_numpy()

# %%
train_data = Molecule_data(root='data', dataset='train_data_set',y=None,smile_graph=None,smiles=None)

# %%
val_data = Molecule_data(root='data', dataset='val_data_set',y=None,smile_graph=None,smiles=None)

# %%
test_data = Molecule_data(root='data', dataset='test_data_set',y=None,smile_graph=None,smiles=None)

# %%
print(len(train_data))
print(len(val_data))
print(len(test_data))
# Out:
# 7314
# 1057
# 2101

# %%
if torch.cuda.is_available():  
    device = "cuda:6"
    print("cuda:6")
else:  
    device = "cpu" 
    print(torch.cuda.is_available())
# Out:
# cuda:6

# %%
# training function at each epoch
def train(model, device, train_loader, optimizer, epoch,loss_fn):
    #print('Training on {} samples...'.format(len(train_loader1.dataset)))
    model.train()
    Loss = []
    for data in train_loader:
        data = data.to(device)
        optimizer.zero_grad()
        output = model(data.x.float(), data.edge_index,data.batch)
        loss = loss_fn(output, data.y.view(-1, 1).float().to(device))
        loss.backward()
        optimizer.step()
        Loss.append(loss.item())
    nploss = np.asarray(Loss)
    avg_loss = np.average(nploss)
    return avg_loss

# %%
def predicting(model, device, loader,loss_fn):
    model.eval()
    total_loss=total_example=0
    with torch.no_grad():
        for data in loader:
            data = data.to(device)
            output = model(data.x.float(), data.edge_index,data.batch)
            loss = loss_fn(output, data.y.view(-1, 1).float().to(device))
            total_loss+=loss
            total_example+=1
    return total_loss/total_example

# %%
class RMSELoss(nn.Module):
    def __init__(self):
        super().__init__()
        self.mse = nn.MSELoss()
        
    def forward(self,yhat,y):
        return torch.sqrt(self.mse(yhat,y))

# %%
#torch.optim.RAdam(params,lr=0.001,betas=(0.9,0.999),eps=1e-08,weight_decay=0)

# %% [markdown]
# # Optuna

# %%
import optuna
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
import math


import logging
import sys

# %%
def objective(trial):
    # hyperparameter setting
    
    batch_size = trial.suggest_int('Batch Size', 16, 128)
    
    train_loder   = DataLoader(train_data,batch_size=batch_size,shuffle=False)
    test_loder  = DataLoader(val_data,batch_size=batch_size,shuffle=False)
    
    LR = 1e-4
    LR1 = 1e-8
    loss_fn = nn.L1Loss()
    learning_rate = trial.suggest_uniform('Learning Rate', LR1, LR)
    
    hidden_channel = trial.suggest_int('Hidden Channels', 112, 300)
    
    num_layer = trial.suggest_int('Number of layers', 2, 8)
    
    dropouts = trial.suggest_uniform('DropOut', 0.0, 0.5)
    
  #  num_timestep = trial.suggest_int('Number Of Timestep', 1, 2)
    
 #   eps_rate = trial.suggest_uniform('eps', 1e-8, 1e-4)
    
    weight_decay = trial.suggest_uniform('Weight Decay', 1e-8, 1e-4)
       
    
    model1 = AttentiveFP(in_channels=114, hidden_channels=hidden_channel, out_channels=1,
                    num_layers=num_layer, num_timesteps=2,
                    dropout=dropouts).to(device)
    
    
    optimizer = torch.optim.Adam(model1.parameters(),lr=learning_rate,betas=(0.9,0.999),
                                 weight_decay=weight_decay,amsgrad=False)
    
   # optimizer = torch.optim.Adam(model1.parameters(), lr=learning_rate)
    
    the_last_loss = 100
    patience = 24
    trigger_times = 0
    count_loss_difference = 0

    for epoch in range(1000):
        train_loss=train(model1, device, train_loder, optimizer, epoch+1,loss_fn)
        test_loss = predicting(model1, device, test_loder,loss_fn)
        
        print('Epoch% d: Train mae: %2.5f\t test mae: %2.5f\t'%(epoch, train_loss, test_loss.item()))

        trial.report(test_loss, epoch)
        # Handle pruning based on the intermediate value.
        if trial.should_prune():
            print("Handle pruning based on the intermediate value.")
            raise optuna.TrialPruned()
            
        # Early stopping
        the_current_loss = test_loss.item()

        if the_current_loss > the_last_loss:
            trigger_times += 1
            print('trigger times:', trigger_times)

            if trigger_times >= patience:
                print('Early stopping!\nStart to test process.')
                break
        else:
            trigger_times = 0
            the_last_loss = the_current_loss
    
    y_pred_arr = []
    target_array = []
    for data in test_loder:
        data = data.to(device)
        y_pred = model1(data.x.float(), data.edge_index,data.batch)
        y_pred_arr.append(y_pred.float())
        target_array.append(data.y.float())
        
    y_ped=torch.cat(y_pred_arr).view(-1).cpu().detach().numpy()
    y_true=torch.cat(target_array).cpu().detach().numpy()
    
    error = mean_absolute_error(y_true,y_ped)
    # output: evaluation score
    return error

# %%
# Add stream handler of stdout to show the messages
optuna.logging.get_logger("optuna").addHandler(logging.StreamHandler(sys.stdout))

study = optuna.create_study(direction='minimize',sampler=optuna.samplers.RandomSampler()
                           ,pruner=optuna.pruners.MedianPruner())
study.optimize(objective, n_trials=2000)
# Out:
# [I 2022-08-02 11:40:44,901] A new study created in memory with name: no-name-64b8502c-9209-4fcb-a4f9-abe480f13608
# A new study created in memory with name: no-name-64b8502c-9209-4fcb-a4f9-abe480f13608
# Epoch 0: Train mae: 1.20591	 test mae: 0.82855
# Epoch 1: Train mae: 0.80446	 test mae: 0.78791
# Epoch 2: Train mae: 0.77476	 test mae: 0.79976
# trigger times: 1
# Epoch 3: Train mae: 0.72574	 test mae: 0.64302
# Epoch 4: Train mae: 0.65857	 test mae: 0.65415
# trigger times: 1
# Epoch 5: Train mae: 0.64304	 test mae: 0.68924
# trigger times: 2
# Epoch 6: Train mae: 0.63801	 test mae: 0.68583
# trigger times: 3
# Epoch 7: Train mae: 0.62332	 test mae: 0.61223
# Epoch 8: Train mae: 0.60969	 test mae: 0.57416
# Epoch 9: Train mae: 0.61107	 test mae: 0.60503
# trigger times: 1
# Epoch 10: Train mae: 0.59666	 test mae: 0.65094
# trigger times: 2
# Epoch 11: Train mae: 0.59128	 test mae: 0.55266
# Epoch 12: Train mae: 0.58641	 test mae: 0.55992
# trigger times: 1
# Epoch 13: Train mae: 0.57104	 test mae: 0.52679
# Epoch 14: Train mae: 0.57292	 test mae: 0.50037
# Epoch 15: Train mae: 0.56052	 test mae: 0.50848
# trigger times: 1
# Epoch 16: Train mae: 0.55217	 test mae: 0.50963
# trigger times: 2
# Epoch 17: Train mae: 0.54894	 test mae: 0.47818
# Epoch 18: Train mae: 0.54303	 test mae: 0.50805
# trigger times: 1
# Epoch 19: Train mae: 0.52390	 test mae: 0.46736
# Epoch 20: Train mae: 0.52574	 test mae: 0.48991
# trigger times: 1
# Epoch 21: Train mae: 0.51675	 test mae: 0.51573
# trigger times: 2
# Epoch 22: Train mae: 0.51603	 test mae: 0.47233
# trigger times: 3
# Epoch 23: Train mae: 0.51080	 test mae: 0.47715
# trigger times: 4
# Epoch 24: Train mae: 0.50762	 test mae: 0.45456
# Epoch 25: Train mae: 0.50197	 test mae: 0.43176
# Epoch 26: Train mae: 0.50493	 test mae: 0.43142
# Epoch 27: Train mae: 0.50703	 test mae: 0.47381
# trigger times: 1
# Epoch 28: Train mae: 0.49928	 test mae: 0.49395
# trigger times: 2
# Epoch 29: Train mae: 0.50095	 test mae: 0.42985
# Epoch 30: Train mae: 0.49344	 test mae: 0.45694
# trigger times: 1
# Epoch 31: Train mae: 0.49245	 test mae: 0.43256
# trigger times: 2
# Epoch 32: Train mae: 0.49337	 test mae: 0.42365
# Epoch 33: Train mae: 0.49216	 test mae: 0.43871
# trigger times: 1
# Epoch 34: Train mae: 0.48610	 test mae: 0.48799
# trigger times: 2
# Epoch 35: Train mae: 0.48439	 test mae: 0.49003
# trigger times: 3
# Epoch 36: Train mae: 0.48301	 test mae: 0.50199
# trigger times: 4
# Epoch 37: Train mae: 0.48230	 test mae: 0.47908
# trigger times: 5
# Epoch 38: Train mae: 0.48029	 test mae: 0.44608
# trigger times: 6
# Epoch 39: Train mae: 0.47901	 test mae: 0.43792
# trigger times: 7
# Epoch 40: Train mae: 0.47741	 test mae: 0.50649
# trigger times: 8
# Epoch 41: Train mae: 0.47783	 test mae: 0.42509
# trigger times: 9
# Epoch 42: Train mae: 0.46970	 test mae: 0.45875
# trigger times: 10
# Epoch 43: Train mae: 0.46909	 test mae: 0.42239
# Epoch 44: Train mae: 0.47247	 test mae: 0.46134
# trigger times: 1
# Epoch 45: Train mae: 0.46786	 test mae: 0.41800
# Epoch 46: Train mae: 0.47392	 test mae: 0.54966
# trigger times: 1
# Epoch 47: Train mae: 0.47392	 test mae: 0.42603
# trigger times: 2
# Epoch 48: Train mae: 0.47467	 test mae: 0.40784
# Epoch 49: Train mae: 0.46258	 test mae: 0.40321
# Epoch 50: Train mae: 0.46545	 test mae: 0.40961
# trigger times: 1
# Epoch 51: Train mae: 0.46500	 test mae: 0.41188
# trigger times: 2
# Epoch 52: Train mae: 0.45951	 test mae: 0.43850
# trigger times: 3
# Epoch 53: Train mae: 0.46012	 test mae: 0.47728
# trigger times: 4
# Epoch 54: Train mae: 0.45732	 test mae: 0.43436
# trigger times: 5
# Epoch 55: Train mae: 0.45609	 test mae: 0.45175
# trigger times: 6
# Epoch 56: Train mae: 0.45334	 test mae: 0.39916
# Epoch 57: Train mae: 0.45168	 test mae: 0.45713
# trigger times: 1
# Epoch 58: Train mae: 0.45481	 test mae: 0.40571
# trigger times: 2
# Epoch 59: Train mae: 0.45089	 test mae: 0.44130
# trigger times: 3
# Epoch 60: Train mae: 0.45317	 test mae: 0.44671
# trigger times: 4
# Epoch 61: Train mae: 0.45052	 test mae: 0.40199
# trigger times: 5
# Epoch 62: Train mae: 0.45121	 test mae: 0.40892
# trigger times: 6
# Epoch 63: Train mae: 0.45228	 test mae: 0.40696
# trigger times: 7
# Epoch 64: Train mae: 0.44652	 test mae: 0.50102
# trigger times: 8
# Epoch 65: Train mae: 0.44314	 test mae: 0.42414
# trigger times: 9
# Epoch 66: Train mae: 0.45193	 test mae: 0.38912
# Epoch 67: Train mae: 0.44695	 test mae: 0.41387
# trigger times: 1
# Epoch 68: Train mae: 0.44558	 test mae: 0.44260
# trigger times: 2
# Epoch 69: Train mae: 0.44800	 test mae: 0.40183
# trigger times: 3
# Epoch 70: Train mae: 0.44401	 test mae: 0.37684
# Epoch 71: Train mae: 0.44273	 test mae: 0.40869
# trigger times: 1
# Epoch 72: Train mae: 0.44367	 test mae: 0.38624
# trigger times: 2
# Epoch 73: Train mae: 0.43776	 test mae: 0.40064
# trigger times: 3
# Epoch 74: Train mae: 0.43904	 test mae: 0.44254
# trigger times: 4
# Epoch 75: Train mae: 0.43889	 test mae: 0.39730
# trigger times: 5
# Epoch 76: Train mae: 0.43598	 test mae: 0.37280
# Epoch 77: Train mae: 0.43641	 test mae: 0.38986
# trigger times: 1
# Epoch 78: Train mae: 0.43213	 test mae: 0.38194
# trigger times: 2
# Epoch 79: Train mae: 0.43190	 test mae: 0.42508
# trigger times: 3
# Epoch 80: Train mae: 0.43127	 test mae: 0.38742
# trigger times: 4
# Epoch 81: Train mae: 0.42885	 test mae: 0.40030
# trigger times: 5
# Epoch 82: Train mae: 0.42745	 test mae: 0.39273
# trigger times: 6
# Epoch 83: Train mae: 0.43454	 test mae: 0.37690
# trigger times: 7
# Epoch 84: Train mae: 0.42998	 test mae: 0.39226
# trigger times: 8
# Epoch 85: Train mae: 0.42541	 test mae: 0.40954
# trigger times: 9
# Epoch 86: Train mae: 0.43143	 test mae: 0.41398
# trigger times: 10
# Epoch 87: Train mae: 0.43105	 test mae: 0.39286
# trigger times: 11
# Epoch 88: Train mae: 0.42418	 test mae: 0.36686
# Epoch 89: Train mae: 0.42737	 test mae: 0.39563
# trigger times: 1
# Epoch 90: Train mae: 0.42617	 test mae: 0.38224
# trigger times: 2
# Epoch 91: Train mae: 0.42175	 test mae: 0.37095
# trigger times: 3
# Epoch 92: Train mae: 0.43007	 test mae: 0.41212
# trigger times: 4
# Epoch 93: Train mae: 0.41993	 test mae: 0.39735
# trigger times: 5
# Epoch 94: Train mae: 0.42607	 test mae: 0.37693
# trigger times: 6
# Epoch 95: Train mae: 0.42399	 test mae: 0.39759
# trigger times: 7
# Epoch 96: Train mae: 0.42194	 test mae: 0.38963
# trigger times: 8
# Epoch 97: Train mae: 0.42163	 test mae: 0.39987
# trigger times: 9
# Epoch 98: Train mae: 0.41937	 test mae: 0.38012
# trigger times: 10
# Epoch 99: Train mae: 0.42294	 test mae: 0.38562
# trigger times: 11
# Epoch 100: Train mae: 0.41979	 test mae: 0.39033
# trigger times: 12
# Epoch 101: Train mae: 0.41929	 test mae: 0.38010
# trigger times: 13
# Epoch 102: Train mae: 0.41929	 test mae: 0.35716
# Epoch 103: Train mae: 0.41963	 test mae: 0.36236
# trigger times: 1
# Epoch 104: Train mae: 0.41599	 test mae: 0.38116
# trigger times: 2
# Epoch 105: Train mae: 0.40943	 test mae: 0.35411
# Epoch 106: Train mae: 0.41227	 test mae: 0.39660
# trigger times: 1
# Epoch 107: Train mae: 0.41454	 test mae: 0.40169
# trigger times: 2
# Epoch 108: Train mae: 0.41388	 test mae: 0.37418
# trigger times: 3
# Epoch 109: Train mae: 0.42079	 test mae: 0.35497
# trigger times: 4
# Epoch 110: Train mae: 0.41156	 test mae: 0.36655
# trigger times: 5
# Epoch 111: Train mae: 0.41344	 test mae: 0.39305
# trigger times: 6
# Epoch 112: Train mae: 0.40962	 test mae: 0.36584
# trigger times: 7
# Epoch 113: Train mae: 0.41346	 test mae: 0.35992
# trigger times: 8
# Epoch 114: Train mae: 0.41057	 test mae: 0.37267
# trigger times: 9
# Epoch 115: Train mae: 0.40438	 test mae: 0.38857
# trigger times: 10
# Epoch 116: Train mae: 0.40694	 test mae: 0.35910
# trigger times: 11
# Epoch 117: Train mae: 0.41425	 test mae: 0.34589
# Epoch 118: Train mae: 0.40597	 test mae: 0.35226
# trigger times: 1
# Epoch 119: Train mae: 0.40732	 test mae: 0.38045
# trigger times: 2
# Epoch 120: Train mae: 0.40710	 test mae: 0.35418
# trigger times: 3
# Epoch 121: Train mae: 0.40769	 test mae: 0.37089
# trigger times: 4
# Epoch 122: Train mae: 0.40126	 test mae: 0.35918
# trigger times: 5
# Epoch 123: Train mae: 0.40941	 test mae: 0.36233
# trigger times: 6
# Epoch 124: Train mae: 0.40390	 test mae: 0.36172
# trigger times: 7
# Epoch 125: Train mae: 0.40625	 test mae: 0.35951
# trigger times: 8
# Epoch 126: Train mae: 0.40303	 test mae: 0.35907
# trigger times: 9
# Epoch 127: Train mae: 0.39475	 test mae: 0.36721
# trigger times: 10
# Epoch 128: Train mae: 0.40011	 test mae: 0.35190
# trigger times: 11
# Epoch 129: Train mae: 0.39998	 test mae: 0.35958
# trigger times: 12
# Epoch 130: Train mae: 0.40015	 test mae: 0.34916
# trigger times: 13
# Epoch 131: Train mae: 0.40462	 test mae: 0.36019
# trigger times: 14
# Epoch 132: Train mae: 0.40066	 test mae: 0.35545
# trigger times: 15
# Epoch 133: Train mae: 0.40296	 test mae: 0.36431
# trigger times: 16
# Epoch 134: Train mae: 0.39704	 test mae: 0.37163
# trigger times: 17
# Epoch 135: Train mae: 0.39976	 test mae: 0.36275
# trigger times: 18
# Epoch 136: Train mae: 0.39992	 test mae: 0.35545
# trigger times: 19
# Epoch 137: Train mae: 0.39804	 test mae: 0.35044
# trigger times: 20
# Epoch 138: Train mae: 0.40055	 test mae: 0.34500
# Epoch 139: Train mae: 0.40466	 test mae: 0.35734
# trigger times: 1
# Epoch 140: Train mae: 0.39631	 test mae: 0.34321
# Epoch 141: Train mae: 0.39619	 test mae: 0.36239
# trigger times: 1
# Epoch 142: Train mae: 0.39985	 test mae: 0.35563
# trigger times: 2
# Epoch 143: Train mae: 0.39701	 test mae: 0.36051
# trigger times: 3
# Epoch 144: Train mae: 0.39283	 test mae: 0.35320
# trigger times: 4
# Epoch 145: Train mae: 0.39470	 test mae: 0.33521
# Epoch 146: Train mae: 0.39686	 test mae: 0.35085
# trigger times: 1
# Epoch 147: Train mae: 0.38982	 test mae: 0.35044
# trigger times: 2
# Epoch 148: Train mae: 0.39172	 test mae: 0.34704
# trigger times: 3
# Epoch 149: Train mae: 0.39246	 test mae: 0.36031
# trigger times: 4
# Epoch 150: Train mae: 0.38912	 test mae: 0.33669
# trigger times: 5
# Epoch 151: Train mae: 0.38961	 test mae: 0.34571
# trigger times: 6
# Epoch 152: Train mae: 0.39066	 test mae: 0.33895
# trigger times: 7
# Epoch 153: Train mae: 0.39339	 test mae: 0.34917
# trigger times: 8
# Epoch 154: Train mae: 0.39299	 test mae: 0.34500
# trigger times: 9
# Epoch 155: Train mae: 0.39299	 test mae: 0.40715
# trigger times: 10
# Epoch 156: Train mae: 0.38800	 test mae: 0.34661
# trigger times: 11
# Epoch 157: Train mae: 0.38871	 test mae: 0.34715
# trigger times: 12
# Epoch 158: Train mae: 0.39035	 test mae: 0.34014
# trigger times: 13
# Epoch 159: Train mae: 0.38448	 test mae: 0.34036
# trigger times: 14
# Epoch 160: Train mae: 0.38510	 test mae: 0.40016
# trigger times: 15
# Epoch 161: Train mae: 0.39395	 test mae: 0.35869
# trigger times: 16
# Epoch 162: Train mae: 0.38323	 test mae: 0.33560
# trigger times: 17
# Epoch 163: Train mae: 0.38600	 test mae: 0.33487
# Epoch 164: Train mae: 0.38555	 test mae: 0.39580
# trigger times: 1
# Epoch 165: Train mae: 0.38362	 test mae: 0.40054
# trigger times: 2
# Epoch 166: Train mae: 0.38316	 test mae: 0.33269
# Epoch 167: Train mae: 0.38342	 test mae: 0.33430
# trigger times: 1
# Epoch 168: Train mae: 0.38674	 test mae: 0.36416
# trigger times: 2
# Epoch 169: Train mae: 0.38040	 test mae: 0.33140
# Epoch 170: Train mae: 0.38323	 test mae: 0.34167
# trigger times: 1
# Epoch 171: Train mae: 0.38447	 test mae: 0.33442
# trigger times: 2
# Epoch 172: Train mae: 0.38360	 test mae: 0.33241
# trigger times: 3
# Epoch 173: Train mae: 0.38032	 test mae: 0.33120
# Epoch 174: Train mae: 0.38224	 test mae: 0.36384
# trigger times: 1
# Epoch 175: Train mae: 0.37834	 test mae: 0.39358
# trigger times: 2
# Epoch 176: Train mae: 0.37931	 test mae: 0.34158
# trigger times: 3
# Epoch 177: Train mae: 0.38170	 test mae: 0.33102
# Epoch 178: Train mae: 0.37447	 test mae: 0.33414
# trigger times: 1
# Epoch 179: Train mae: 0.38039	 test mae: 0.33907
# trigger times: 2
# Epoch 180: Train mae: 0.38328	 test mae: 0.35184
# trigger times: 3
# Epoch 181: Train mae: 0.38316	 test mae: 0.33480
# trigger times: 4
# Epoch 182: Train mae: 0.37827	 test mae: 0.35187
# trigger times: 5
# Epoch 183: Train mae: 0.38002	 test mae: 0.35495
# trigger times: 6
# Epoch 184: Train mae: 0.36977	 test mae: 0.32924
# Epoch 185: Train mae: 0.37487	 test mae: 0.36466
# trigger times: 1
# Epoch 186: Train mae: 0.38065	 test mae: 0.35405
# trigger times: 2
# Epoch 187: Train mae: 0.37655	 test mae: 0.35139
# trigger times: 3
# Epoch 188: Train mae: 0.37857	 test mae: 0.34987
# trigger times: 4
# Epoch 189: Train mae: 0.37204	 test mae: 0.33583
# trigger times: 5
# Epoch 190: Train mae: 0.37838	 test mae: 0.33218
# trigger times: 6
# Epoch 191: Train mae: 0.37759	 test mae: 0.32903
# Epoch 192: Train mae: 0.37522	 test mae: 0.33145
# trigger times: 1
# Epoch 193: Train mae: 0.37532	 test mae: 0.33089
# trigger times: 2
# Epoch 194: Train mae: 0.36923	 test mae: 0.32855
# Epoch 195: Train mae: 0.37107	 test mae: 0.35221
# trigger times: 1
# Epoch 196: Train mae: 0.37940	 test mae: 0.33586
# trigger times: 2
# Epoch 197: Train mae: 0.37242	 test mae: 0.32849
# Epoch 198: Train mae: 0.37629	 test mae: 0.34704
# trigger times: 1
# Epoch 199: Train mae: 0.37329	 test mae: 0.34882
# trigger times: 2
# Epoch 200: Train mae: 0.37139	 test mae: 0.37966
# trigger times: 3
# Epoch 201: Train mae: 0.37522	 test mae: 0.32814
# Epoch 202: Train mae: 0.37222	 test mae: 0.32624
# Epoch 203: Train mae: 0.37363	 test mae: 0.32901
# trigger times: 1
# Epoch 204: Train mae: 0.36832	 test mae: 0.34160
# trigger times: 2
# Epoch 205: Train mae: 0.37044	 test mae: 0.33042
# trigger times: 3
# Epoch 206: Train mae: 0.37352	 test mae: 0.33496
# trigger times: 4
# Epoch 207: Train mae: 0.37120	 test mae: 0.33638
# trigger times: 5
# Epoch 208: Train mae: 0.36909	 test mae: 0.32864
# trigger times: 6
# Epoch 209: Train mae: 0.36861	 test mae: 0.32704
# trigger times: 7
# Epoch 210: Train mae: 0.37487	 test mae: 0.33139
# trigger times: 8
# Epoch 211: Train mae: 0.36811	 test mae: 0.33088
# trigger times: 9
# Epoch 212: Train mae: 0.36537	 test mae: 0.32394
# Epoch 213: Train mae: 0.36536	 test mae: 0.32769
# trigger times: 1
# Epoch 214: Train mae: 0.36653	 test mae: 0.32801
# trigger times: 2
# Epoch 215: Train mae: 0.36440	 test mae: 0.34035
# trigger times: 3
# Epoch 216: Train mae: 0.36938	 test mae: 0.32394
# Epoch 217: Train mae: 0.36798	 test mae: 0.33568
# trigger times: 1
# Epoch 218: Train mae: 0.36624	 test mae: 0.33968
# trigger times: 2
# Epoch 219: Train mae: 0.36531	 test mae: 0.32386
# Epoch 220: Train mae: 0.37187	 test mae: 0.33071
# trigger times: 1
# Epoch 221: Train mae: 0.37062	 test mae: 0.33077
# trigger times: 2
# Epoch 222: Train mae: 0.36227	 test mae: 0.33074
# trigger times: 3
# Epoch 223: Train mae: 0.36262	 test mae: 0.34845
# trigger times: 4
# Epoch 224: Train mae: 0.36792	 test mae: 0.33006
# trigger times: 5
# Epoch 225: Train mae: 0.36553	 test mae: 0.33410
# trigger times: 6
# Epoch 226: Train mae: 0.36580	 test mae: 0.33252
# trigger times: 7
# Epoch 227: Train mae: 0.36212	 test mae: 0.34898
# trigger times: 8
# Epoch 228: Train mae: 0.36466	 test mae: 0.32963
# trigger times: 9
# Epoch 229: Train mae: 0.36565	 test mae: 0.33465
# trigger times: 10
# Epoch 230: Train mae: 0.36238	 test mae: 0.32507
# trigger times: 11
# Epoch 231: Train mae: 0.36179	 test mae: 0.32989
# trigger times: 12
# Epoch 232: Train mae: 0.36562	 test mae: 0.32299
# Epoch 233: Train mae: 0.35888	 test mae: 0.33768
# trigger times: 1
# Epoch 234: Train mae: 0.36082	 test mae: 0.31785
# Epoch 235: Train mae: 0.36552	 test mae: 0.32232
# trigger times: 1
# Epoch 236: Train mae: 0.35990	 test mae: 0.32222
# trigger times: 2
# Epoch 237: Train mae: 0.36042	 test mae: 0.32961
# trigger times: 3
# Epoch 238: Train mae: 0.36270	 test mae: 0.31673
# Epoch 239: Train mae: 0.36543	 test mae: 0.34746
# trigger times: 1
# Epoch 240: Train mae: 0.36216	 test mae: 0.32045
# trigger times: 2
# Epoch 241: Train mae: 0.36132	 test mae: 0.32415
# trigger times: 3
# Epoch 242: Train mae: 0.35747	 test mae: 0.33667
# trigger times: 4
# Epoch 243: Train mae: 0.35917	 test mae: 0.32399
# trigger times: 5
# Epoch 244: Train mae: 0.35860	 test mae: 0.31821
# trigger times: 6
# Epoch 245: Train mae: 0.35432	 test mae: 0.33501
# trigger times: 7
# Epoch 246: Train mae: 0.36255	 test mae: 0.32147
# trigger times: 8
# Epoch 247: Train mae: 0.35362	 test mae: 0.32555
# trigger times: 9
# Epoch 248: Train mae: 0.36272	 test mae: 0.32832
# trigger times: 10
# Epoch 249: Train mae: 0.35727	 test mae: 0.32395
# trigger times: 11
# Epoch 250: Train mae: 0.35646	 test mae: 0.31907
# trigger times: 12
# Epoch 251: Train mae: 0.36048	 test mae: 0.32285
# trigger times: 13
# Epoch 252: Train mae: 0.35721	 test mae: 0.32033
# trigger times: 14
# Epoch 253: Train mae: 0.35093	 test mae: 0.31855
# trigger times: 15
# Epoch 254: Train mae: 0.35281	 test mae: 0.33729
# trigger times: 16
# Epoch 255: Train mae: 0.35492	 test mae: 0.32306
# trigger times: 17
# Epoch 256: Train mae: 0.35574	 test mae: 0.32011
# trigger times: 18
# Epoch 257: Train mae: 0.35045	 test mae: 0.34559
# trigger times: 19
# Epoch 258: Train mae: 0.35444	 test mae: 0.34282
# trigger times: 20
# Epoch 259: Train mae: 0.36169	 test mae: 0.31782
# trigger times: 21
# Epoch 260: Train mae: 0.35235	 test mae: 0.32148
# trigger times: 22
# Epoch 261: Train mae: 0.35346	 test mae: 0.31535
# Epoch 262: Train mae: 0.35662	 test mae: 0.32377
# trigger times: 1
# Epoch 263: Train mae: 0.35590	 test mae: 0.32018
# trigger times: 2
# Epoch 264: Train mae: 0.35173	 test mae: 0.33396
# trigger times: 3
# Epoch 265: Train mae: 0.35270	 test mae: 0.31827
# trigger times: 4
# Epoch 266: Train mae: 0.35116	 test mae: 0.32018
# trigger times: 5
# Epoch 267: Train mae: 0.34820	 test mae: 0.33809
# trigger times: 6
# Epoch 268: Train mae: 0.35559	 test mae: 0.32402
# trigger times: 7
# Epoch 269: Train mae: 0.35194	 test mae: 0.32838
# trigger times: 8
# Epoch 270: Train mae: 0.34912	 test mae: 0.31995
# trigger times: 9
# Epoch 271: Train mae: 0.35170	 test mae: 0.31470
# Epoch 272: Train mae: 0.35343	 test mae: 0.31784
# trigger times: 1
# Epoch 273: Train mae: 0.34963	 test mae: 0.33243
# trigger times: 2
# Epoch 274: Train mae: 0.35196	 test mae: 0.31779
# trigger times: 3
# Epoch 275: Train mae: 0.35512	 test mae: 0.32775
# trigger times: 4
# Epoch 276: Train mae: 0.35409	 test mae: 0.31434
# Epoch 277: Train mae: 0.34917	 test mae: 0.31845
# trigger times: 1
# Epoch 278: Train mae: 0.34812	 test mae: 0.31724
# trigger times: 2
# Epoch 279: Train mae: 0.35089	 test mae: 0.32193
# trigger times: 3
# Epoch 280: Train mae: 0.34318	 test mae: 0.32828
# trigger times: 4
# Epoch 281: Train mae: 0.34728	 test mae: 0.31256
# Epoch 282: Train mae: 0.35203	 test mae: 0.33591
# trigger times: 1
# Epoch 283: Train mae: 0.35001	 test mae: 0.31437
# trigger times: 2
# Epoch 284: Train mae: 0.34925	 test mae: 0.32180
# trigger times: 3
# Epoch 285: Train mae: 0.34191	 test mae: 0.31421
# trigger times: 4
# Epoch 286: Train mae: 0.35105	 test mae: 0.33286
# trigger times: 5
# Epoch 287: Train mae: 0.34574	 test mae: 0.32797
# trigger times: 6
# Epoch 288: Train mae: 0.34374	 test mae: 0.31993
# trigger times: 7
# Epoch 289: Train mae: 0.34530	 test mae: 0.31581
# trigger times: 8
# Epoch 290: Train mae: 0.34407	 test mae: 0.31499
# trigger times: 9
# Epoch 291: Train mae: 0.34785	 test mae: 0.32903
# trigger times: 10
# Epoch 292: Train mae: 0.34711	 test mae: 0.32427
# trigger times: 11
# Epoch 293: Train mae: 0.34268	 test mae: 0.31472
# trigger times: 12
# Epoch 294: Train mae: 0.34246	 test mae: 0.31828
# trigger times: 13
# Epoch 295: Train mae: 0.34960	 test mae: 0.32112
# trigger times: 14
# Epoch 296: Train mae: 0.34521	 test mae: 0.32738
# trigger times: 15
# Epoch 297: Train mae: 0.34295	 test mae: 0.32362
# trigger times: 16
# Epoch 298: Train mae: 0.34794	 test mae: 0.32766
# trigger times: 17
# Epoch 299: Train mae: 0.34936	 test mae: 0.31483
# trigger times: 18
# Epoch 300: Train mae: 0.34224	 test mae: 0.31653
# trigger times: 19
# Epoch 301: Train mae: 0.34228	 test mae: 0.31799
# trigger times: 20
# Epoch 302: Train mae: 0.34407	 test mae: 0.32352
# trigger times: 21
# Epoch 303: Train mae: 0.34499	 test mae: 0.31046
# Epoch 304: Train mae: 0.34103	 test mae: 0.31968
# trigger times: 1
# Epoch 305: Train mae: 0.34494	 test mae: 0.31897
# trigger times: 2
# Epoch 306: Train mae: 0.34363	 test mae: 0.31003
# Epoch 307: Train mae: 0.34361	 test mae: 0.32446
# trigger times: 1
# Epoch 308: Train mae: 0.34463	 test mae: 0.31204
# trigger times: 2
# Epoch 309: Train mae: 0.34056	 test mae: 0.31793
# trigger times: 3
# Epoch 310: Train mae: 0.34285	 test mae: 0.31928
# trigger times: 4
# Epoch 311: Train mae: 0.34273	 test mae: 0.31737
# trigger times: 5
# Epoch 312: Train mae: 0.33760	 test mae: 0.31328
# trigger times: 6
# Epoch 313: Train mae: 0.34177	 test mae: 0.31689
# trigger times: 7
# Epoch 314: Train mae: 0.34011	 test mae: 0.31606
# trigger times: 8
# Epoch 315: Train mae: 0.33972	 test mae: 0.31374
# trigger times: 9
# Epoch 316: Train mae: 0.34200	 test mae: 0.30964
# Epoch 317: Train mae: 0.33869	 test mae: 0.31148
# trigger times: 1
# Epoch 318: Train mae: 0.34136	 test mae: 0.31346
# trigger times: 2
# Epoch 319: Train mae: 0.34287	 test mae: 0.30961
# Epoch 320: Train mae: 0.33841	 test mae: 0.32199
# trigger times: 1
# Epoch 321: Train mae: 0.33879	 test mae: 0.30692
# Epoch 322: Train mae: 0.33664	 test mae: 0.31313
# trigger times: 1
# Epoch 323: Train mae: 0.33704	 test mae: 0.32056
# trigger times: 2
# Epoch 324: Train mae: 0.33578	 test mae: 0.30875
# trigger times: 3
# Epoch 325: Train mae: 0.33529	 test mae: 0.31262
# trigger times: 4
# Epoch 326: Train mae: 0.33707	 test mae: 0.31636
# trigger times: 5
# Epoch 327: Train mae: 0.33340	 test mae: 0.31815
# trigger times: 6
# Epoch 328: Train mae: 0.33585	 test mae: 0.32067
# trigger times: 7
# Epoch 329: Train mae: 0.33967	 test mae: 0.30636
# Epoch 330: Train mae: 0.33799	 test mae: 0.30967
# trigger times: 1
# Epoch 331: Train mae: 0.33877	 test mae: 0.31804
# trigger times: 2
# Epoch 332: Train mae: 0.34011	 test mae: 0.32047
# trigger times: 3
# Epoch 333: Train mae: 0.33698	 test mae: 0.30728
# trigger times: 4
# Epoch 334: Train mae: 0.33673	 test mae: 0.30473
# Epoch 335: Train mae: 0.33896	 test mae: 0.31074
# trigger times: 1
# Epoch 336: Train mae: 0.33446	 test mae: 0.30967
# trigger times: 2
# Epoch 337: Train mae: 0.33363	 test mae: 0.32387
# trigger times: 3
# Epoch 338: Train mae: 0.33663	 test mae: 0.31337
# trigger times: 4
# Epoch 339: Train mae: 0.33172	 test mae: 0.31161
# trigger times: 5
# Epoch 340: Train mae: 0.33944	 test mae: 0.30832
# trigger times: 6
# Epoch 341: Train mae: 0.33301	 test mae: 0.31107
# trigger times: 7
# Epoch 342: Train mae: 0.32989	 test mae: 0.31417
# trigger times: 8
# Epoch 343: Train mae: 0.33669	 test mae: 0.31662
# trigger times: 9
# Epoch 344: Train mae: 0.33267	 test mae: 0.32303
# trigger times: 10
# Epoch 345: Train mae: 0.33291	 test mae: 0.31052
# trigger times: 11
# Epoch 346: Train mae: 0.33363	 test mae: 0.31200
# trigger times: 12
# Epoch 347: Train mae: 0.33135	 test mae: 0.31188
# trigger times: 13
# Epoch 348: Train mae: 0.33261	 test mae: 0.31205
# trigger times: 14
# Epoch 349: Train mae: 0.33257	 test mae: 0.30920
# trigger times: 15
# Epoch 350: Train mae: 0.33151	 test mae: 0.30453
# Epoch 351: Train mae: 0.32947	 test mae: 0.31777
# trigger times: 1
# Epoch 352: Train mae: 0.33013	 test mae: 0.31785
# trigger times: 2
# Epoch 353: Train mae: 0.33267	 test mae: 0.30866
# trigger times: 3
# Epoch 354: Train mae: 0.33109	 test mae: 0.30811
# trigger times: 4
# Epoch 355: Train mae: 0.33325	 test mae: 0.30676
# trigger times: 5
# Epoch 356: Train mae: 0.32977	 test mae: 0.30525
# trigger times: 6
# Epoch 357: Train mae: 0.33227	 test mae: 0.30258
# Epoch 358: Train mae: 0.33471	 test mae: 0.30413
# trigger times: 1
# Epoch 359: Train mae: 0.33224	 test mae: 0.30648
# trigger times: 2
# Epoch 360: Train mae: 0.32923	 test mae: 0.30816
# trigger times: 3
# Epoch 361: Train mae: 0.32911	 test mae: 0.30977
# trigger times: 4
# Epoch 362: Train mae: 0.32609	 test mae: 0.30670
# trigger times: 5
# Epoch 363: Train mae: 0.32895	 test mae: 0.30241
# Epoch 364: Train mae: 0.33051	 test mae: 0.30804
# trigger times: 1
# Epoch 365: Train mae: 0.32355	 test mae: 0.30070
# Epoch 366: Train mae: 0.32906	 test mae: 0.31534
# trigger times: 1
# Epoch 367: Train mae: 0.32698	 test mae: 0.30700
# trigger times: 2
# Epoch 368: Train mae: 0.32687	 test mae: 0.33379
# trigger times: 3
# Epoch 369: Train mae: 0.33006	 test mae: 0.31651
# trigger times: 4
# Epoch 370: Train mae: 0.32740	 test mae: 0.30405
# trigger times: 5
# Epoch 371: Train mae: 0.32843	 test mae: 0.30125
# trigger times: 6
# Epoch 372: Train mae: 0.32968	 test mae: 0.30459
# trigger times: 7
# Epoch 373: Train mae: 0.32571	 test mae: 0.30603
# trigger times: 8
# Epoch 374: Train mae: 0.32481	 test mae: 0.32640
# trigger times: 9
# Epoch 375: Train mae: 0.32510	 test mae: 0.30359
# trigger times: 10
# Epoch 376: Train mae: 0.32601	 test mae: 0.30233
# trigger times: 11
# Epoch 377: Train mae: 0.32869	 test mae: 0.30482
# trigger times: 12
# Epoch 378: Train mae: 0.32021	 test mae: 0.30191
# trigger times: 13
# Epoch 379: Train mae: 0.32113	 test mae: 0.30300
# trigger times: 14
# Epoch 380: Train mae: 0.32337	 test mae: 0.30232
# trigger times: 15
# Epoch 381: Train mae: 0.32266	 test mae: 0.30846
# trigger times: 16
# Epoch 382: Train mae: 0.32115	 test mae: 0.30809
# trigger times: 17
# Epoch 383: Train mae: 0.32201	 test mae: 0.29880
# Epoch 384: Train mae: 0.32699	 test mae: 0.29844
# Epoch 385: Train mae: 0.32467	 test mae: 0.30349
# trigger times: 1
# Epoch 386: Train mae: 0.32101	 test mae: 0.32008
# trigger times: 2
# Epoch 387: Train mae: 0.32190	 test mae: 0.30111
# trigger times: 3
# Epoch 388: Train mae: 0.32398	 test mae: 0.30037
# trigger times: 4
# Epoch 389: Train mae: 0.32255	 test mae: 0.30474
# trigger times: 5
# Epoch 390: Train mae: 0.32342	 test mae: 0.29800
# Epoch 391: Train mae: 0.32477	 test mae: 0.30070
# trigger times: 1
# Epoch 392: Train mae: 0.31875	 test mae: 0.30356
# trigger times: 2
# Epoch 393: Train mae: 0.31823	 test mae: 0.29787
# Epoch 394: Train mae: 0.31875	 test mae: 0.30346
# trigger times: 1
# Epoch 395: Train mae: 0.32053	 test mae: 0.31444
# trigger times: 2
# Epoch 396: Train mae: 0.32122	 test mae: 0.30068
# trigger times: 3
# Epoch 397: Train mae: 0.32288	 test mae: 0.29878
# trigger times: 4
# Epoch 398: Train mae: 0.31780	 test mae: 0.30052
# trigger times: 5
# Epoch 399: Train mae: 0.32054	 test mae: 0.29927
# trigger times: 6
# Epoch 400: Train mae: 0.32102	 test mae: 0.30038
# trigger times: 7
# Epoch 401: Train mae: 0.32293	 test mae: 0.29951
# trigger times: 8
# Epoch 402: Train mae: 0.31574	 test mae: 0.29338
# Epoch 403: Train mae: 0.31871	 test mae: 0.30217
# trigger times: 1
# Epoch 404: Train mae: 0.31586	 test mae: 0.30096
# trigger times: 2
# Epoch 405: Train mae: 0.31677	 test mae: 0.29987
# trigger times: 3
# Epoch 406: Train mae: 0.31699	 test mae: 0.30570
# trigger times: 4
# Epoch 407: Train mae: 0.31565	 test mae: 0.30017
# trigger times: 5
# Epoch 408: Train mae: 0.31840	 test mae: 0.30806
# trigger times: 6
# Epoch 409: Train mae: 0.31678	 test mae: 0.29823
# trigger times: 7
# Epoch 410: Train mae: 0.31781	 test mae: 0.29971
# trigger times: 8
# Epoch 411: Train mae: 0.31758	 test mae: 0.30971
# trigger times: 9
# Epoch 412: Train mae: 0.31371	 test mae: 0.30253
# trigger times: 10
# Epoch 413: Train mae: 0.31536	 test mae: 0.30409
# trigger times: 11
# Epoch 414: Train mae: 0.31956	 test mae: 0.29433
# trigger times: 12
# Epoch 415: Train mae: 0.31297	 test mae: 0.29912
# trigger times: 13
# Epoch 416: Train mae: 0.31596	 test mae: 0.29907
# trigger times: 14
# Epoch 417: Train mae: 0.31451	 test mae: 0.29583
# trigger times: 15
# Epoch 418: Train mae: 0.31543	 test mae: 0.29729
# trigger times: 16
# Epoch 419: Train mae: 0.31604	 test mae: 0.29321
# Epoch 420: Train mae: 0.31647	 test mae: 0.29724
# trigger times: 1
# Epoch 421: Train mae: 0.31908	 test mae: 0.29422
# trigger times: 2
# Epoch 422: Train mae: 0.31254	 test mae: 0.29469
# trigger times: 3
# Epoch 423: Train mae: 0.31461	 test mae: 0.29862
# trigger times: 4
# Epoch 424: Train mae: 0.31686	 test mae: 0.29390
# trigger times: 5
# Epoch 425: Train mae: 0.31624	 test mae: 0.29682
# trigger times: 6
# Epoch 426: Train mae: 0.31298	 test mae: 0.29924
# trigger times: 7
# Epoch 427: Train mae: 0.31196	 test mae: 0.29660
# trigger times: 8
# Epoch 428: Train mae: 0.31307	 test mae: 0.29767
# trigger times: 9
# Epoch 429: Train mae: 0.31390	 test mae: 0.29906
# trigger times: 10
# Epoch 430: Train mae: 0.31379	 test mae: 0.29799
# trigger times: 11
# Epoch 431: Train mae: 0.31166	 test mae: 0.29636
# trigger times: 12
# Epoch 432: Train mae: 0.31064	 test mae: 0.30574
# trigger times: 13
# Epoch 433: Train mae: 0.31234	 test mae: 0.29158
# Epoch 434: Train mae: 0.30929	 test mae: 0.30014
# trigger times: 1
# Epoch 435: Train mae: 0.31229	 test mae: 0.29430
# trigger times: 2
# Epoch 436: Train mae: 0.31070	 test mae: 0.29540
# trigger times: 3
# Epoch 437: Train mae: 0.31238	 test mae: 0.29122
# Epoch 438: Train mae: 0.30645	 test mae: 0.29881
# trigger times: 1
# Epoch 439: Train mae: 0.31143	 test mae: 0.29333
# trigger times: 2
# Epoch 440: Train mae: 0.31233	 test mae: 0.29520
# trigger times: 3
# Epoch 441: Train mae: 0.30918	 test mae: 0.28972
# Epoch 442: Train mae: 0.31407	 test mae: 0.28991
# trigger times: 1
# Epoch 443: Train mae: 0.31098	 test mae: 0.29239
# trigger times: 2
# Epoch 444: Train mae: 0.31184	 test mae: 0.29362
# trigger times: 3
# Epoch 445: Train mae: 0.30388	 test mae: 0.30517
# trigger times: 4
# Epoch 446: Train mae: 0.30953	 test mae: 0.29708
# trigger times: 5
# Epoch 447: Train mae: 0.31048	 test mae: 0.29564
# trigger times: 6
# Epoch 448: Train mae: 0.31113	 test mae: 0.29445
# trigger times: 7
# Epoch 449: Train mae: 0.30905	 test mae: 0.28997
# trigger times: 8
# Epoch 450: Train mae: 0.30296	 test mae: 0.29080
# trigger times: 9
# Epoch 451: Train mae: 0.30875	 test mae: 0.29120
# trigger times: 10
# Epoch 452: Train mae: 0.31004	 test mae: 0.29437
# trigger times: 11
# Epoch 453: Train mae: 0.30623	 test mae: 0.29267
# trigger times: 12
# Epoch 454: Train mae: 0.30824	 test mae: 0.29222
# trigger times: 13
# Epoch 455: Train mae: 0.30986	 test mae: 0.29184
# trigger times: 14
# Epoch 456: Train mae: 0.31183	 test mae: 0.29170
# trigger times: 15
# Epoch 457: Train mae: 0.30946	 test mae: 0.29840
# trigger times: 16
# Epoch 458: Train mae: 0.30744	 test mae: 0.29744
# trigger times: 17
# Epoch 459: Train mae: 0.30850	 test mae: 0.30304
# trigger times: 18
# Epoch 460: Train mae: 0.30711	 test mae: 0.29138
# trigger times: 19
# Epoch 461: Train mae: 0.30850	 test mae: 0.29664
# trigger times: 20
# Epoch 462: Train mae: 0.30861	 test mae: 0.29828
# trigger times: 21
# Epoch 463: Train mae: 0.30786	 test mae: 0.29097
# trigger times: 22
# Epoch 464: Train mae: 0.30384	 test mae: 0.28985
# trigger times: 23
# Epoch 465: Train mae: 0.30642	 test mae: 0.29244
# trigger times: 24
# Early stopping!
# Start to test process.
# [I 2022-08-02 13:33:30,068] Trial 0 finished with value: 0.29315128922462463 and parameters: {'Batch Size': 26, 'Learning Rate': 8.941908545618662e-05, 'Hidden Channels': 183, 'Number of layers': 7, 'DropOut': 0.3450172012987748, 'Weight Decay': 3.6452664447743336e-05}. Best is trial 0 with value: 0.29315128922462463.
# Trial 0 finished with value: 0.29315128922462463 and parameters: {'Batch Size': 26, 'Learning Rate': 8.941908545618662e-05, 'Hidden Channels': 183, 'Number of layers': 7, 'DropOut': 0.3450172012987748, 'Weight Decay': 3.6452664447743336e-05}. Best is trial 0 with value: 0.29315128922462463.
# Epoch 0: Train mae: 2.43863	 test mae: 1.69632
# Epoch 1: Train mae: 1.39352	 test mae: 0.93538
# Epoch 2: Train mae: 1.02074	 test mae: 0.88171
# Epoch 3: Train mae: 0.92040	 test mae: 0.83871
# Epoch 4: Train mae: 0.86808	 test mae: 0.82292
# Epoch 5: Train mae: 0.84930	 test mae: 0.82145
# Epoch 6: Train mae: 0.84400	 test mae: 0.82852
# trigger times: 1
# Epoch 7: Train mae: 0.80603	 test mae: 0.83183
# trigger times: 2
# Epoch 8: Train mae: 0.80561	 test mae: 0.81067
# Epoch 9: Train mae: 0.80145	 test mae: 0.81483
# trigger times: 1
# Epoch 10: Train mae: 0.79826	 test mae: 0.81030
# Epoch 11: Train mae: 0.80302	 test mae: 0.80217
# Epoch 12: Train mae: 0.79214	 test mae: 0.78959
# Epoch 13: Train mae: 0.79129	 test mae: 0.79782
# trigger times: 1
# Epoch 14: Train mae: 0.78910	 test mae: 0.78468
# Epoch 15: Train mae: 0.78629	 test mae: 0.79304
# trigger times: 1
# Epoch 16: Train mae: 0.78656	 test mae: 0.78607
# trigger times: 2
# Epoch 17: Train mae: 0.76816	 test mae: 0.78587
# trigger times: 3
# Epoch 18: Train mae: 0.76561	 test mae: 0.80550
# trigger times: 4
# Epoch 19: Train mae: 0.73643	 test mae: 0.71301
# Epoch 20: Train mae: 0.72051	 test mae: 0.69346
# Epoch 21: Train mae: 0.72347	 test mae: 0.69056
# Epoch 22: Train mae: 0.69508	 test mae: 0.66964
# Epoch 23: Train mae: 0.69871	 test mae: 0.66615
# Epoch 24: Train mae: 0.68574	 test mae: 0.63956
# Epoch 25: Train mae: 0.68872	 test mae: 0.64881
# trigger times: 1
# Epoch 26: Train mae: 0.68297	 test mae: 0.63281
# Epoch 27: Train mae: 0.67382	 test mae: 0.64609
# trigger times: 1
# Epoch 28: Train mae: 0.66390	 test mae: 0.62375
# Epoch 29: Train mae: 0.66585	 test mae: 0.62635
# trigger times: 1
# Epoch 30: Train mae: 0.66292	 test mae: 0.62737
# trigger times: 2
# Epoch 31: Train mae: 0.66488	 test mae: 0.61752
# Epoch 32: Train mae: 0.66717	 test mae: 0.62274
# trigger times: 1
# Epoch 33: Train mae: 0.65304	 test mae: 0.61722
# Epoch 34: Train mae: 0.66435	 test mae: 0.60474
# Epoch 35: Train mae: 0.65644	 test mae: 0.59169
# Epoch 36: Train mae: 0.64981	 test mae: 0.59312
# trigger times: 1
# Epoch 37: Train mae: 0.65521	 test mae: 0.59420
# trigger times: 2
# Epoch 38: Train mae: 0.64127	 test mae: 0.59469
# trigger times: 3
# Epoch 39: Train mae: 0.64251	 test mae: 0.59140
# Epoch 40: Train mae: 0.64300	 test mae: 0.57952
# Epoch 41: Train mae: 0.64456	 test mae: 0.57702
# Epoch 42: Train mae: 0.64378	 test mae: 0.58845
# trigger times: 1
# Epoch 43: Train mae: 0.64262	 test mae: 0.60851
# trigger times: 2
# Epoch 44: Train mae: 0.63560	 test mae: 0.60054
# trigger times: 3
# Epoch 45: Train mae: 0.63947	 test mae: 0.59958
# trigger times: 4
# Epoch 46: Train mae: 0.63351	 test mae: 0.61989
# trigger times: 5
# Epoch 47: Train mae: 0.63845	 test mae: 0.59196
# trigger times: 6
# Epoch 48: Train mae: 0.62773	 test mae: 0.59066
# trigger times: 7
# Epoch 49: Train mae: 0.62881	 test mae: 0.59091
# trigger times: 8
# Epoch 50: Train mae: 0.62907	 test mae: 0.59538
# trigger times: 9
# Epoch 51: Train mae: 0.62512	 test mae: 0.58469
# trigger times: 10
# Epoch 52: Train mae: 0.62590	 test mae: 0.56931
# Epoch 53: Train mae: 0.62496	 test mae: 0.60998
# trigger times: 1
# Epoch 54: Train mae: 0.62824	 test mae: 0.59321
# trigger times: 2
# Epoch 55: Train mae: 0.62474	 test mae: 0.58560
# trigger times: 3
# Epoch 56: Train mae: 0.61670	 test mae: 0.57428
# trigger times: 4
# Epoch 57: Train mae: 0.62371	 test mae: 0.58236
# trigger times: 5
# Epoch 58: Train mae: 0.62229	 test mae: 0.56360
# Epoch 59: Train mae: 0.61593	 test mae: 0.56598
# trigger times: 1
# Epoch 60: Train mae: 0.62065	 test mae: 0.56865
# trigger times: 2
# Epoch 61: Train mae: 0.61252	 test mae: 0.58999
# trigger times: 3
# Epoch 62: Train mae: 0.61729	 test mae: 0.56090
# Epoch 63: Train mae: 0.61381	 test mae: 0.57107
# trigger times: 1
# Epoch 64: Train mae: 0.60778	 test mae: 0.60765
# trigger times: 2
# Epoch 65: Train mae: 0.60956	 test mae: 0.58915
# trigger times: 3
# Epoch 66: Train mae: 0.60415	 test mae: 0.60818
# trigger times: 4
# Epoch 67: Train mae: 0.61649	 test mae: 0.55923
# Epoch 68: Train mae: 0.60570	 test mae: 0.57414
# trigger times: 1
# Epoch 69: Train mae: 0.61348	 test mae: 0.57626
# trigger times: 2
# Epoch 70: Train mae: 0.61190	 test mae: 0.55054
# Epoch 71: Train mae: 0.60797	 test mae: 0.57318
# trigger times: 1
# Epoch 72: Train mae: 0.60732	 test mae: 0.56890
# trigger times: 2
# Epoch 73: Train mae: 0.60174	 test mae: 0.55572
# trigger times: 3
# Epoch 74: Train mae: 0.59551	 test mae: 0.56546
# trigger times: 4
# Epoch 75: Train mae: 0.59061	 test mae: 0.54472
# Epoch 76: Train mae: 0.59451	 test mae: 0.55335
# trigger times: 1
# Epoch 77: Train mae: 0.59862	 test mae: 0.55212
# trigger times: 2
# Epoch 78: Train mae: 0.59328	 test mae: 0.56336
# trigger times: 3
# Epoch 79: Train mae: 0.59197	 test mae: 0.57149
# trigger times: 4
# Epoch 80: Train mae: 0.59310	 test mae: 0.53319
# Epoch 81: Train mae: 0.59154	 test mae: 0.53356
# trigger times: 1
# Epoch 82: Train mae: 0.59042	 test mae: 0.57983
# trigger times: 2
# Epoch 83: Train mae: 0.58791	 test mae: 0.55341
# trigger times: 3
# Epoch 84: Train mae: 0.57824	 test mae: 0.57225
# trigger times: 4
# Epoch 85: Train mae: 0.58575	 test mae: 0.54319
# trigger times: 5
# Epoch 86: Train mae: 0.58632	 test mae: 0.58314
# trigger times: 6
# Epoch 87: Train mae: 0.58693	 test mae: 0.51817
# Epoch 88: Train mae: 0.58332	 test mae: 0.54870
# trigger times: 1
# Epoch 89: Train mae: 0.57933	 test mae: 0.58283
# trigger times: 2
# Epoch 90: Train mae: 0.57829	 test mae: 0.58135
# trigger times: 3
# Epoch 91: Train mae: 0.57993	 test mae: 0.56310
# trigger times: 4
# Epoch 92: Train mae: 0.57391	 test mae: 0.54888
# trigger times: 5
# Epoch 93: Train mae: 0.57423	 test mae: 0.57942
# trigger times: 6
# Epoch 94: Train mae: 0.58194	 test mae: 0.56122
# trigger times: 7
# Epoch 95: Train mae: 0.57123	 test mae: 0.52637
# trigger times: 8
# Epoch 96: Train mae: 0.56730	 test mae: 0.54429
# trigger times: 9
# Epoch 97: Train mae: 0.56840	 test mae: 0.53768
# trigger times: 10
# Epoch 98: Train mae: 0.57508	 test mae: 0.56023
# trigger times: 11
# Epoch 99: Train mae: 0.56892	 test mae: 0.55327
# trigger times: 12
# Epoch 100: Train mae: 0.56664	 test mae: 0.56052
# trigger times: 13
# Epoch 101: Train mae: 0.56138	 test mae: 0.53237
# trigger times: 14
# Epoch 102: Train mae: 0.56970	 test mae: 0.59719
# trigger times: 15
# Epoch 103: Train mae: 0.56367	 test mae: 0.56610
# trigger times: 16
# Epoch 104: Train mae: 0.55948	 test mae: 0.59549
# trigger times: 17
# Epoch 105: Train mae: 0.55480	 test mae: 0.50033
# Epoch 106: Train mae: 0.55351	 test mae: 0.56411
# trigger times: 1
# Epoch 107: Train mae: 0.56768	 test mae: 0.57593
# trigger times: 2
# Epoch 108: Train mae: 0.55829	 test mae: 0.55457
# trigger times: 3
# Epoch 109: Train mae: 0.55845	 test mae: 0.53031
# trigger times: 4
# Epoch 110: Train mae: 0.55419	 test mae: 0.59909
# trigger times: 5
# Epoch 111: Train mae: 0.55545	 test mae: 0.53001
# trigger times: 6
# Epoch 112: Train mae: 0.55252	 test mae: 0.56554
# trigger times: 7
# Epoch 113: Train mae: 0.55307	 test mae: 0.55529
# trigger times: 8
# Epoch 114: Train mae: 0.55368	 test mae: 0.51679
# trigger times: 9
# Epoch 115: Train mae: 0.55561	 test mae: 0.53468
# trigger times: 10
# Epoch 116: Train mae: 0.55267	 test mae: 0.53371
# trigger times: 11
# Epoch 117: Train mae: 0.54631	 test mae: 0.56757
# trigger times: 12
# Epoch 118: Train mae: 0.54778	 test mae: 0.61751
# trigger times: 13
# Epoch 119: Train mae: 0.55061	 test mae: 0.56617
# trigger times: 14
# Epoch 120: Train mae: 0.53857	 test mae: 0.60239
# trigger times: 15
# Epoch 121: Train mae: 0.54724	 test mae: 0.55003
# trigger times: 16
# Epoch 122: Train mae: 0.54392	 test mae: 0.54561
# trigger times: 17
# Epoch 123: Train mae: 0.54335	 test mae: 0.56814
# trigger times: 18
# Epoch 124: Train mae: 0.54164	 test mae: 0.53060
# trigger times: 19
# Epoch 125: Train mae: 0.53877	 test mae: 0.55457
# trigger times: 20
# Epoch 126: Train mae: 0.53956	 test mae: 0.51936
# trigger times: 21
# Epoch 127: Train mae: 0.53710	 test mae: 0.52665
# trigger times: 22
# Epoch 128: Train mae: 0.53751	 test mae: 0.57584
# trigger times: 23
# Epoch 129: Train mae: 0.53932	 test mae: 0.56382
# trigger times: 24
# Early stopping!
# Start to test process.
# [I 2022-08-02 13:44:17,558] Trial 1 finished with value: 0.5613318681716919 and parameters: {'Batch Size': 84, 'Learning Rate': 3.842936263440232e-05, 'Hidden Channels': 140, 'Number of layers': 7, 'DropOut': 0.43640565434393513, 'Weight Decay': 5.659969791451963e-05}. Best is trial 0 with value: 0.29315128922462463.
# Trial 1 finished with value: 0.5613318681716919 and parameters: {'Batch Size': 84, 'Learning Rate': 3.842936263440232e-05, 'Hidden Channels': 140, 'Number of layers': 7, 'DropOut': 0.43640565434393513, 'Weight Decay': 5.659969791451963e-05}. Best is trial 0 with value: 0.29315128922462463.
# Epoch 0: Train mae: 2.12424	 test mae: 1.31979
# Epoch 1: Train mae: 1.04375	 test mae: 0.86698
# Epoch 2: Train mae: 0.91484	 test mae: 0.83098
# Epoch 3: Train mae: 0.87071	 test mae: 0.81251
# Epoch 4: Train mae: 0.84635	 test mae: 0.79219
# Epoch 5: Train mae: 0.82248	 test mae: 0.77971
# Epoch 6: Train mae: 0.81432	 test mae: 0.76723
# Epoch 7: Train mae: 0.79389	 test mae: 0.77502
# trigger times: 1
# Epoch 8: Train mae: 0.77602	 test mae: 0.74901
# Epoch 9: Train mae: 0.75995	 test mae: 0.73385
# Epoch 10: Train mae: 0.74426	 test mae: 0.73284
# Epoch 11: Train mae: 0.72266	 test mae: 0.72047
# Epoch 12: Train mae: 0.70750	 test mae: 0.69085
# Epoch 13: Train mae: 0.69290	 test mae: 0.72019
# trigger times: 1
# Epoch 14: Train mae: 0.68636	 test mae: 0.68431
# Epoch 15: Train mae: 0.68526	 test mae: 0.67785
# Epoch 16: Train mae: 0.66388	 test mae: 0.66264
# Epoch 17: Train mae: 0.66988	 test mae: 0.70167
# trigger times: 1
# Epoch 18: Train mae: 0.66301	 test mae: 0.63402
# Epoch 19: Train mae: 0.65819	 test mae: 0.62676
# Epoch 20: Train mae: 0.65738	 test mae: 0.61876
# Epoch 21: Train mae: 0.64515	 test mae: 0.63732
# trigger times: 1
# Epoch 22: Train mae: 0.64793	 test mae: 0.61597
# Epoch 23: Train mae: 0.64668	 test mae: 0.61641
# trigger times: 1
# Epoch 24: Train mae: 0.64409	 test mae: 0.61069
# Epoch 25: Train mae: 0.63074	 test mae: 0.62574
# trigger times: 1
# Epoch 26: Train mae: 0.63625	 test mae: 0.60905
# Epoch 27: Train mae: 0.63215	 test mae: 0.60554
# Epoch 28: Train mae: 0.63369	 test mae: 0.60500
# Epoch 29: Train mae: 0.62822	 test mae: 0.61093
# trigger times: 1
# Epoch 30: Train mae: 0.62993	 test mae: 0.59540
# Epoch 31: Train mae: 0.62930	 test mae: 0.59409
# Epoch 32: Train mae: 0.61926	 test mae: 0.59832
# trigger times: 1

# %%
print('Minimum mean squared error: ' + str(study.best_value))
print('Best parameter: ' + str(study.best_params))

# %% [markdown]
# # Vizualization

# %%
fig = optuna.visualization.plot_param_importances(study)
fig.show()
fig.savefig('optunaParms')   # save the figure to file

# %%
fig = optuna.visualization.plot_slice(study, params=["Learning Rate", "DropOut"])
fig.show()

# %%
trials = study.trials_dataframe()

# %%
x = trials['params_Number of layers']
y = trials['value']
